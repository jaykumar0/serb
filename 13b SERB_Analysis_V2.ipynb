# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
pd.set_option("max_colwidth", 140)

# %%
# Read the cleaned file 
#df = pd.read_excel('ed2\SERB_all_5_yrs_V2_ed.xlsx')
df = pd.read_csv('processed/SERB_all_5_yrs_V3.csv')
df.shape
# Out:
# (4667, 11)

# %%
df.head(10)
# Out:
#           Discipline                          Sub Area  \
# 0  Chemical Sciences  Inorganic and Physical Chemistry
# 1  Chemical Sciences  Inorganic and Physical Chemistry
# 2  Chemical Sciences  Inorganic and Physical Chemistry
# 3  Chemical Sciences  Inorganic and Physical Chemistry
# 4  Chemical Sciences  Inorganic and Physical Chemistry
# 5  Chemical Sciences  Inorganic and Physical Chemistry
# 6  Chemical Sciences  Inorganic and Physical Chemistry
# 7  Chemical Sciences  Inorganic and Physical Chemistry
# 8  Chemical Sciences  Inorganic and Physical Chemistry
# 9  Chemical Sciences  Inorganic and Physical Chemistry
#
#                                                                                                                                          Title  \
# 0                                      Advanced Materials Towards Electrocatalytic Oxygen Evolution Reaction For Sustainable Energy Conversion
# 1                                                                                       Chemistry In Self-Assembled Coordination Architectures
# 2  Detoxification of Arsenic Compounds: Enzyme Mimetic Studies To Understand The Methylation of Arsenic By Ar(III) S-Adenosylmethione (SAM)...
# 3                                                    Investigation of Zintl phases as efficient thermoelectric materials for energy conversion
# 4  High Potency of Complex Dietary Β-Glucan Fibers As Cholesterol And Low-Density Lipoprotein Lowering Agents: A Comprehensive Mechanistic ...
# 5      Photophysics of Acetylene Bridged Push-Pull Systems: Torsional Effects On Local, Intramolecular Charge Transfer And Aggregate Emissions
# 6                                                                                       Metal-Based Targeted Photodynamic Therapy In Red Light
# 7                                                                     Chemical Transformations of Clathrate Hydrates Under Ultra- High Vacuum*
# 8                     Investigation of Charge Transport In Proteins And Organic Polymers of Relevance To Electrochemical Processes And Systems
# 9                                Computational Studies On Charge Transfer And Hole Migration Dynamics In Functionalized Bimetallic Nanocluster
#
#                                                                                                             PI Details  \
# 0                                 Tharamani Chikka Nagaiah, Indian Institute of Technology Ropar, Ropar,Punjab, 140001
# 1                         Partha Sarathi Mukherjee, Indian Institute of Science,Bangalore, Bangalore,Karnataka, 560012
# 2                                     Gouriprasanna Roy, Shiv Nadar University, Gautambudh Nagar,Uttar Pradesh, 203207
# 3  Manoj Raama Varma, National Institute For Interdisciplinary Science & Technology, Thiruvananthapuram,Kerala,6 95019
# 4                   Durba Roy, Birla Institute of Technology And Science Pilani-Hyderabad, Hyderabad,Telangana, 500078
# 5                                Ashok Kumar Mishra, Indian Institute of Technology Madras, Chennai,Tamil Nadu, 600036
# 6                         Akhil Ranjan Chakravarty, Indian Institute of Science,Bangalore, Bangalore,Karnataka, 560012
# 7                                         T Pradeep, Indian Institute of Technology Madras, Chennai,Tamil Nadu, 600036
# 8                      Aninda Jiban Bhattacharyya, Indian Institute of Science, Bangalore, Bangalore,Karnataka, 560012
# 9                                                  Ganga Periyasamy, Bangalore University, Bangalore,Karnataka, 560056
#
#    Total Cost     Year                   Professor  \
# 0     5783370  2019-20    Tharamani Chikka Nagaiah
# 1     5519890  2019-20    Partha Sarathi Mukherjee
# 2     5953775  2019-20           Gouriprasanna Roy
# 3     3034800  2019-20           Manoj Raama Varma
# 4     3666520  2019-20                   Durba Roy
# 5     4573890  2019-20          Ashok Kumar Mishra
# 6     4128695  2019-20    Akhil Ranjan Chakravarty
# 7     7653890  2019-20                   T Pradeep
# 8     5657695  2019-20  Aninda Jiban Bhattacharyya
# 9     3178485  2019-20            Ganga Periyasamy
#
#                                                                                          Institute  \
# 0                                         Indian Institute Of Technology Ropar,Ropar,Punjab,140001
# 1                                 Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 2                                      Shiv Nadar University,Gautambudh Nagar,Uttar Pradesh,203207
# 3  National Institute For Interdisciplinary Science & Technology,Thiruvananthapuram,Kerala,6 95019
# 4            Birla Institute Of Technology And Science Pilani-Hyderabad,Hyderabad,Telangana,500078
# 5                                  Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036
# 6                                 Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 7                                  Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036
# 8                                 Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 9                                                  Bangalore University,Bangalore,Karnataka,560056
#
#     PinCode          State        TIER-I
# 0  140001.0         Punjab          IITs
# 1  560012.0      Karnataka          IISc
# 2  203207.0  Uttar Pradesh        Others
# 3       NaN         Kerala  Other TIER-I
# 4  500078.0      Telangana          BITS
# 5  600036.0     Tamil Nadu          IITs
# 6  560012.0      Karnataka          IISc
# 7  600036.0     Tamil Nadu          IITs
# 8  560012.0      Karnataka          IISc
# 9  560056.0      Karnataka        Others

# %% [markdown]
# # Analysis

# %% [markdown]
# # Q1
#
# >**What is the trend of total sanctioned projects over the years (cumulative as well as discipline-wise)**

# %%
dt = df.groupby('Year',as_index=False).agg(
    TotalCost = ('Total Cost',sum),
    NumProjects= ('Total Cost','count')
)
(dt.style
.highlight_min(color='lightgreen')
.highlight_max(color='lightblue'))
# Out:
# <style  type="text/css" >
# #T_2fe24_row0_col1,#T_2fe24_row0_col2{
#             background-color:  lightgreen;
#         }#T_2fe24_row3_col1,#T_2fe24_row3_col2{
#             background-color:  lightblue;
#         }</style><table id="T_2fe24_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >TotalCost</th>        <th class="col_heading level0 col2" >NumProjects</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fe24_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2fe24_row0_col0" class="data row0 col0" >2015-16</td>
#                         <td id="T_2fe24_row0_col1" class="data row0 col1" >2582231298</td>
#                         <td id="T_2fe24_row0_col2" class="data row0 col2" >641</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe24_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2fe24_row1_col0" class="data row1 col0" >2016-17</td>
#                         <td id="T_2fe24_row1_col1" class="data row1 col1" >4044115807</td>
#                         <td id="T_2fe24_row1_col2" class="data row1 col2" >952</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe24_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2fe24_row2_col0" class="data row2 col0" >2017-18</td>
#                         <td id="T_2fe24_row2_col1" class="data row2 col1" >2972699474</td>
#                         <td id="T_2fe24_row2_col2" class="data row2 col2" >757</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe24_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2fe24_row3_col0" class="data row3 col0" >2018-19</td>
#                         <td id="T_2fe24_row3_col1" class="data row3 col1" >4620260577</td>
#                         <td id="T_2fe24_row3_col2" class="data row3 col2" >1276</td>
#             </tr>
#             <tr>
#                         <th id="T_2fe24_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2fe24_row4_col0" class="data row4 col0" >2019-20</td>
#                         <td id="T_2fe24_row4_col1" class="data row4 col1" >4425341515</td>
#                         <td id="T_2fe24_row4_col2" class="data row4 col2" >1041</td>
#             </tr>
#     </tbody></table>

# %%
df.groupby('Year')['Total Cost'].sum()
# Out:
# Year
# 2015-16    2582231298
# 2016-17    4044115807
# 2017-18    2972699474
# 2018-19    4620260577
# 2019-20    4425341515
# Name: Total Cost, dtype: int64

# %%
# By Num  Projects
df.groupby('Year')['Total Cost'].count()
# Out:
# Year
# 2015-16     641
# 2016-17     952
# 2017-18     757
# 2018-19    1276
# 2019-20    1041
# Name: Total Cost, dtype: int64

# %%
df.groupby('Discipline')['Total Cost'].sum()
# Out:
# Discipline
# Chemical Sciences               3528249485
# EMR                             2582231298
# Earth & Atmospheric Sciences     535430142
# Engineering Sciences            3076077327
# Life Sciences                   6547182048
# Mathematical Sciences            225156619
# Physical Sciences               2150321752
# Name: Total Cost, dtype: int64

# %%
# By Number of Projects
df.groupby('Discipline')['Total Cost'].count()
# Out:
# Discipline
# Chemical Sciences                784
# EMR                              641
# Earth & Atmospheric Sciences     150
# Engineering Sciences             730
# Life Sciences                   1594
# Mathematical Sciences            138
# Physical Sciences                630
# Name: Total Cost, dtype: int64

# %% [markdown]
# # Q2
# >**Distribution of the sanctioned projects across disciplines (total_cost vs count)**

# %%
dt = df.groupby(['Year','Discipline']).agg(
    TotalCost = ('Total Cost',sum),
    NumProjects= ('Total Cost','count')
)
dt
# Out:
#                                        TotalCost  NumProjects
# Year    Discipline
# 2015-16 EMR                           2582231298          641
# 2016-17 Chemical Sciences              958906750          206
#         Earth & Atmospheric Sciences   105234272           33
#         Engineering Sciences           615133186          137
#         Life Sciences                 1657586028          366
#         Mathematical Sciences           50796984           38
#         Physical Sciences              656458587          172
# 2017-18 Chemical Sciences              766350011          178
#         Earth & Atmospheric Sciences    59461200           16
#         Engineering Sciences           629103799          151
#         Life Sciences                 1069522265          260
#         Mathematical Sciences           33570729           24
#         Physical Sciences              414691470          128
# 2018-19 Chemical Sciences              906805036          209
#         Earth & Atmospheric Sciences   223832420           62
#         Engineering Sciences           706862667          189
#         Life Sciences                 2170994999          598
#         Mathematical Sciences           79011765           47
#         Physical Sciences              532753690          171
# 2019-20 Chemical Sciences              896187688          191
#         Earth & Atmospheric Sciences   146902250           39
#         Engineering Sciences          1124977675          253
#         Life Sciences                 1649078756          370
#         Mathematical Sciences           61777141           29
#         Physical Sciences              546418005          159

# %%
# By Cost 
df.groupby(['Year','Discipline'])['Total Cost'].sum()
# Out:
# Year     Discipline
# 2015-16  EMR                             2582231298
# 2016-17  Chemical Sciences                958906750
#          Earth & Atmospheric Sciences     105234272
#          Engineering Sciences             615133186
#          Life Sciences                   1657586028
#          Mathematical Sciences             50796984
#          Physical Sciences                656458587
# 2017-18  Chemical Sciences                766350011
#          Earth & Atmospheric Sciences      59461200
#          Engineering Sciences             629103799
#          Life Sciences                   1069522265
#          Mathematical Sciences             33570729
#          Physical Sciences                414691470
# 2018-19  Chemical Sciences                906805036
#          Earth & Atmospheric Sciences     223832420
#          Engineering Sciences             706862667
#          Life Sciences                   2170994999
#          Mathematical Sciences             79011765
#          Physical Sciences                532753690
# 2019-20  Chemical Sciences                896187688
#          Earth & Atmospheric Sciences     146902250
#          Engineering Sciences            1124977675
#          Life Sciences                   1649078756
#          Mathematical Sciences             61777141
#          Physical Sciences                546418005
# Name: Total Cost, dtype: int64

# %%
#By Count
df.groupby(['Year','Discipline'])['Total Cost'].count()
# Out:
# Year     Discipline
# 2015-16  EMR                             641
# 2016-17  Chemical Sciences               206
#          Earth & Atmospheric Sciences     33
#          Engineering Sciences            137
#          Life Sciences                   366
#          Mathematical Sciences            38
#          Physical Sciences               172
# 2017-18  Chemical Sciences               178
#          Earth & Atmospheric Sciences     16
#          Engineering Sciences            151
#          Life Sciences                   260
#          Mathematical Sciences            24
#          Physical Sciences               128
# 2018-19  Chemical Sciences               209
#          Earth & Atmospheric Sciences     62
#          Engineering Sciences            189
#          Life Sciences                   598
#          Mathematical Sciences            47
#          Physical Sciences               171
# 2019-20  Chemical Sciences               191
#          Earth & Atmospheric Sciences     39
#          Engineering Sciences            253
#          Life Sciences                   370
#          Mathematical Sciences            29
#          Physical Sciences               159
# Name: Total Cost, dtype: int64

# %% [markdown]
# # Q3
# >**Distribution of the sanctioned projects across TIER-I insti (total_cost vs count)**<br>
# >**What is the distibution of sanctioned projects (total_cost vs count) for TIER-I insti**<br>
# >**What is the distibution of sanctioned projects for IITs**<br>

# %%
df.groupby('TIER-I')['Total Cost'].sum()
# Out:
# TIER-I
# BITS              282438046
# CSIR Labs         820876304
# IISER             952958676
# IISc              898776329
# IITs             3943434930
# JNCASR            130159996
# NITs              681127361
# Other TIER-I      452463087
# Others          10338588903
# VIT               143825039
# Name: Total Cost, dtype: int64

# %%
df.groupby('TIER-I')['Total Cost'].count()
# Out:
# TIER-I
# BITS              91
# CSIR Labs        218
# IISER            200
# IISc             172
# IITs             911
# JNCASR            25
# NITs             203
# Other TIER-I      91
# Others          2710
# VIT               46
# Name: Total Cost, dtype: int64

# %%
df['TIER-I'].value_counts(dropna=False)
# Out:
# Others          2710
# IITs             911
# CSIR Labs        218
# NITs             203
# IISER            200
# IISc             172
# Other TIER-I      91
# BITS              91
# VIT               46
# JNCASR            25
# Name: TIER-I, dtype: int64

# %%
df.groupby(['Year','TIER-I'])['Total Cost'].sum()
# Out:
# Year     TIER-I
# 2015-16  BITS              20135829
#          CSIR Labs        125954015
#          IISER            144662074
#          IISc             131642672
#          IITs             570044232
#          JNCASR            30930686
#          NITs              64016200
#          Other TIER-I      91570068
#          Others          1396712522
#          VIT                6563000
# 2016-17  BITS             101894545
#          CSIR Labs        193338546
#          IISER            180122267
#          IISc             265893315
#          IITs             622680407
#          JNCASR            31311712
#          NITs             129739332
#          Other TIER-I      80819834
#          Others          2393458958
#          VIT               44856891
# 2017-18  BITS              54725459
#          CSIR Labs        154265948
#          IISER            138194005
#          IISc             129399193
#          IITs             478614133
#          NITs             173218930
#          Other TIER-I      98607424
#          Others          1722812305
#          VIT               22862077
# 2018-19  BITS              57784065
#          CSIR Labs        209325055
#          IISER            254505863
#          IISc             173103733
#          IITs             876507507
#          JNCASR            17237870
#          NITs             184504689
#          Other TIER-I      90024171
#          Others          2706275481
#          VIT               50992143
# 2019-20  BITS              47898148
#          CSIR Labs        137992740
#          IISER            235474467
#          IISc             198737416
#          IITs            1395588651
#          JNCASR            50679728
#          NITs             129648210
#          Other TIER-I      91441590
#          Others          2119329637
#          VIT               18550928
# Name: Total Cost, dtype: int64

# %%
df.groupby(['Year','TIER-I'])['Total Cost'].count()
# Out:
# Year     TIER-I
# 2015-16  BITS              7
#          CSIR Labs        38
#          IISER            34
#          IISc             27
#          IITs            130
#          JNCASR            6
#          NITs             18
#          Other TIER-I     15
#          Others          364
#          VIT               2
# 2016-17  BITS             33
#          CSIR Labs        45
#          IISER            29
#          IISc             38
#          IITs            141
#          JNCASR            6
#          NITs             40
#          Other TIER-I     16
#          Others          590
#          VIT              14
# 2017-18  BITS             17
#          CSIR Labs        39
#          IISER            31
#          IISc             25
#          IITs            108
#          NITs             53
#          Other TIER-I     15
#          Others          461
#          VIT               8
# 2018-19  BITS             19
#          CSIR Labs        62
#          IISER            60
#          IISc             44
#          IITs            229
#          JNCASR            4
#          NITs             54
#          Other TIER-I     23
#          Others          764
#          VIT              17
# 2019-20  BITS             15
#          CSIR Labs        34
#          IISER            46
#          IISc             38
#          IITs            303
#          JNCASR            9
#          NITs             38
#          Other TIER-I     22
#          Others          531
#          VIT               5
# Name: Total Cost, dtype: int64

# %%
df[df['TIER-I'] == 'IITs'].groupby(['Year','TIER-I'])['Total Cost'].sum()
# Out:
# Year     TIER-I
# 2015-16  IITs       570044232
# 2016-17  IITs       622680407
# 2017-18  IITs       478614133
# 2018-19  IITs       876507507
# 2019-20  IITs      1395588651
# Name: Total Cost, dtype: int64

# %%
df[df['TIER-I'] == 'IITs'].groupby(['Year','TIER-I'])['Total Cost'].count()
# Out:
# Year     TIER-I
# 2015-16  IITs      130
# 2016-17  IITs      141
# 2017-18  IITs      108
# 2018-19  IITs      229
# 2019-20  IITs      303
# Name: Total Cost, dtype: int64

# %%
df[df['TIER-I'] == 'IITs'].groupby('Year')['Total Cost'].count()
# Out:
# Year
# 2015-16    130
# 2016-17    141
# 2017-18    108
# 2018-19    229
# 2019-20    303
# Name: Total Cost, dtype: int64

# %%
df[df['TIER-I'] == 'IITs'].groupby(['Year','Discipline'])['Total Cost'].sum()
# Out:
# Year     Discipline
# 2015-16  EMR                             570044232
# 2016-17  Chemical Sciences               155655110
#          Earth & Atmospheric Sciences     24699700
#          Engineering Sciences            246347474
#          Life Sciences                    87776999
#          Mathematical Sciences            13496869
#          Physical Sciences                94704255
# 2017-18  Chemical Sciences               118218015
#          Earth & Atmospheric Sciences     12974400
#          Engineering Sciences            251876816
#          Life Sciences                    47227661
#          Mathematical Sciences             8765124
#          Physical Sciences                39552117
# 2018-19  Chemical Sciences               286594023
#          Earth & Atmospheric Sciences     31418800
#          Engineering Sciences            358841647
#          Life Sciences                    91446427
#          Mathematical Sciences            20574836
#          Physical Sciences                87631774
# 2019-20  Chemical Sciences               257243805
#          Earth & Atmospheric Sciences     48643490
#          Engineering Sciences            782262319
#          Life Sciences                   150098456
#          Mathematical Sciences            19507914
#          Physical Sciences               137832667
# Name: Total Cost, dtype: int64

# %%
df[df['TIER-I'] == 'IITs'].groupby(['Year','Discipline'])['Total Cost'].count()
# Out:
# Year     Discipline
# 2015-16  EMR                             130
# 2016-17  Chemical Sciences                34
#          Earth & Atmospheric Sciences      6
#          Engineering Sciences             50
#          Life Sciences                    18
#          Mathematical Sciences             8
#          Physical Sciences                25
# 2017-18  Chemical Sciences                26
#          Earth & Atmospheric Sciences      3
#          Engineering Sciences             53
#          Life Sciences                     9
#          Mathematical Sciences             5
#          Physical Sciences                12
# 2018-19  Chemical Sciences                60
#          Earth & Atmospheric Sciences     10
#          Engineering Sciences             90
#          Life Sciences                    27
#          Mathematical Sciences            12
#          Physical Sciences                30
# 2019-20  Chemical Sciences                48
#          Earth & Atmospheric Sciences     12
#          Engineering Sciences            168
#          Life Sciences                    31
#          Mathematical Sciences             8
#          Physical Sciences                36
# Name: Total Cost, dtype: int64

# %%
df[df['TIER-I'].isin(['IITs','IISc','BITS']) ].groupby(['Year','TIER-I'])['Total Cost'].sum()
# Out:
# Year     TIER-I
# 2015-16  BITS        20135829
#          IISc       131642672
#          IITs       570044232
# 2016-17  BITS       101894545
#          IISc       265893315
#          IITs       622680407
# 2017-18  BITS        54725459
#          IISc       129399193
#          IITs       478614133
# 2018-19  BITS        57784065
#          IISc       173103733
#          IITs       876507507
# 2019-20  BITS        47898148
#          IISc       198737416
#          IITs      1395588651
# Name: Total Cost, dtype: int64

# %% [markdown]
# # Q4
# >**Maximum amount of funding is received by which institute (count, cost) ... cumulative for 1 year**
#
#
# >**Maximum amount of funding is received by which institute (cost) ... as a single datapoint**

# %%
# Count - how many projects 
df['Institute'].value_counts().head(20)
# Out:
# Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012                          92
# Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076                           92
# Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036                           75
# Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016                         68
# Indian Institute Of Technology Kharagpur,Kharagpur,West Bengal,721302                     61
# Indian Institute Of Technology Delhi,New Delhi,Delhi,110016                               50
# Indian Institute Of Technology Roorkee,Roorkee,Uttarakhand,247667                         44
# University Of Hyderabad,Hyderabad,Telangana,500046                                        44
# All India Institute Of Medical Sciences,Delhi,New Delhi,Delhi,110029                      39
# Indian Institute Of Technology Guwahati,Guwahati,Assam,781039                             37
# Indian Institute Of Science Education And Research Bhopal,Bhopal,Madhya Pradesh,462023    34
# Indian Institute Of Science Education And Research Pune,Pune,Maharashtra,411008           33
# Indian Association For The Cultivation Of Science,Kolkata,West Bengal,700032              31
# Central Drug Research Institute,Lucknow,Uttar Pradesh,226031                              30
# Indian Institute Of Science Education And Research Kolkata,Nadia,West Bengal,741246       29
# National Institute Of Technology Rourkela,Rourkela,Orissa,769008                          29
# University Of Delhi,Delhi,Delhi,110007                                                    28
# Banaras Hindu University,Varanasi,Uttar Pradesh,221005                                    27
# Jawaharlal Nehru University,New Delhi,Delhi,110067                                        25
# National Chemical Laboratory,Pune,Maharashtra,411008                                      23
# Name: Institute, dtype: int64

# %%
# By Cost - Institues getting most money
dt = df.groupby('Institute',as_index=False)['Total Cost'].sum()
#dt.sort_values(by=['Total Cost'],ascending =False).head(10)
cm = sns.light_palette("lightblue", as_cmap=True)
dt.sort_values(by=['Total Cost'],ascending =False).head(10).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_900d8_row0_col1{
#             background-color:  #add8e6;
#             color:  #000000;
#         }#T_900d8_row1_col1{
#             background-color:  #b1d9e7;
#             color:  #000000;
#         }#T_900d8_row2_col1{
#             background-color:  #cae3eb;
#             color:  #000000;
#         }#T_900d8_row3_col1{
#             background-color:  #cbe3eb;
#             color:  #000000;
#         }#T_900d8_row4_col1{
#             background-color:  #dfebef;
#             color:  #000000;
#         }#T_900d8_row5_col1{
#             background-color:  #e6edf0;
#             color:  #000000;
#         }#T_900d8_row6_col1{
#             background-color:  #e9eef0;
#             color:  #000000;
#         }#T_900d8_row7_col1{
#             background-color:  #ecf0f1;
#             color:  #000000;
#         }#T_900d8_row8_col1{
#             background-color:  #eef1f1;
#             color:  #000000;
#         }#T_900d8_row9_col1{
#             background-color:  #eff1f2;
#             color:  #000000;
#         }</style><table id="T_900d8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Institute</th>        <th class="col_heading level0 col1" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_900d8_level0_row0" class="row_heading level0 row0" >1176</th>
#                         <td id="T_900d8_row0_col0" class="data row0 col0" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_900d8_row0_col1" class="data row0 col1" >443368513</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row1" class="row_heading level0 row1" >1153</th>
#                         <td id="T_900d8_row1_col0" class="data row1 col0" >Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012</td>
#                         <td id="T_900d8_row1_col1" class="data row1 col1" >426750014</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row2" class="row_heading level0 row2" >1226</th>
#                         <td id="T_900d8_row2_col0" class="data row2 col0" >Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036</td>
#                         <td id="T_900d8_row2_col1" class="data row2 col1" >324963921</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row3" class="row_heading level0 row3" >1216</th>
#                         <td id="T_900d8_row3_col0" class="data row3 col0" >Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016</td>
#                         <td id="T_900d8_row3_col1" class="data row3 col1" >320734536</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row4" class="row_heading level0 row4" >1221</th>
#                         <td id="T_900d8_row4_col0" class="data row4 col0" >Indian Institute Of Technology Kharagpur,Kharagpur,West Bengal,721302</td>
#                         <td id="T_900d8_row4_col1" class="data row4 col1" >237538683</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row5" class="row_heading level0 row5" >1183</th>
#                         <td id="T_900d8_row5_col0" class="data row5 col0" >Indian Institute Of Technology Delhi,New Delhi,Delhi,110016</td>
#                         <td id="T_900d8_row5_col1" class="data row5 col1" >207385440</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row6" class="row_heading level0 row6" >2039</th>
#                         <td id="T_900d8_row6_col0" class="data row6 col0" >University Of Hyderabad,Hyderabad,Telangana,500046</td>
#                         <td id="T_900d8_row6_col1" class="data row6 col1" >195771145</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row7" class="row_heading level0 row7" >1237</th>
#                         <td id="T_900d8_row7_col0" class="data row7 col0" >Indian Institute Of Technology Roorkee,Roorkee,Uttarakhand,247667</td>
#                         <td id="T_900d8_row7_col1" class="data row7 col1" >184548699</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row8" class="row_heading level0 row8" >1132</th>
#                         <td id="T_900d8_row8_col0" class="data row8 col0" >Indian Institute Of Science Education And Research Pune,Pune,Maharashtra,411008</td>
#                         <td id="T_900d8_row8_col1" class="data row8 col1" >172814982</td>
#             </tr>
#             <tr>
#                         <th id="T_900d8_level0_row9" class="row_heading level0 row9" >40</th>
#                         <td id="T_900d8_row9_col0" class="data row9 col0" >All India Institute Of Medical Sciences,Delhi,New Delhi,Delhi,110029</td>
#                         <td id="T_900d8_row9_col1" class="data row9 col1" >168838175</td>
#             </tr>
#     </tbody></table>

# %%
dt.nlargest(10,'Total Cost')
# Out:
#                                                                             Institute  \
# 1176                  Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076
# 1153                 Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 1226                  Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036
# 1216                Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016
# 1221            Indian Institute Of Technology Kharagpur,Kharagpur,West Bengal,721302
# 1183                      Indian Institute Of Technology Delhi,New Delhi,Delhi,110016
# 2039                               University Of Hyderabad,Hyderabad,Telangana,500046
# 1237                Indian Institute Of Technology Roorkee,Roorkee,Uttarakhand,247667
# 1132  Indian Institute Of Science Education And Research Pune,Pune,Maharashtra,411008
# 40               All India Institute Of Medical Sciences,Delhi,New Delhi,Delhi,110029
#
#       Total Cost
# 1176   443368513
# 1153   426750014
# 1226   324963921
# 1216   320734536
# 1221   237538683
# 1183   207385440
# 2039   195771145
# 1237   184548699
# 1132   172814982
# 40     168838175

# %%
# Least money
cm = sns.light_palette('pink', as_cmap=True)
dt.nsmallest(10,'Total Cost').style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_47658_row0_col1{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_47658_row1_col1{
#             background-color:  #fbd2d9;
#             color:  #000000;
#         }#T_47658_row2_col1{
#             background-color:  #fbd1d8;
#             color:  #000000;
#         }#T_47658_row3_col1{
#             background-color:  #fdc8d1;
#             color:  #000000;
#         }#T_47658_row4_col1{
#             background-color:  #fdc7d1;
#             color:  #000000;
#         }#T_47658_row5_col1{
#             background-color:  #fec6cf;
#             color:  #000000;
#         }#T_47658_row6_col1{
#             background-color:  #fec2cd;
#             color:  #000000;
#         }#T_47658_row7_col1{
#             background-color:  #ffc2cc;
#             color:  #000000;
#         }#T_47658_row8_col1{
#             background-color:  #ffc1cc;
#             color:  #000000;
#         }#T_47658_row9_col1{
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }</style><table id="T_47658_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Institute</th>        <th class="col_heading level0 col1" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_47658_level0_row0" class="row_heading level0 row0" >844</th>
#                         <td id="T_47658_row0_col0" class="data row0 col0" >Dept. Of Biology,Indian Institute Of Science Education And Research,Indian Institute Of Science Education And Research-Pune,Pune,Maharashtra,411008.</td>
#                         <td id="T_47658_row0_col1" class="data row0 col1" >135000</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row1" class="row_heading level0 row1" >1927</th>
#                         <td id="T_47658_row1_col0" class="data row1 col0" >Sri Dharmasthala Manjunatheshwara College Of Ayurveda & Hospitals,Udupi,Karnataka,574118</td>
#                         <td id="T_47658_row1_col1" class="data row1 col1" >365000</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_47658_row2_col0" class="data row2 col0" >Balaji Utthan Sansthan,Patna,Bihar,</td>
#                         <td id="T_47658_row2_col1" class="data row2 col1" >374000</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row3" class="row_heading level0 row3" >376</th>
#                         <td id="T_47658_row3_col0" class="data row3 col0" >Department Of Biochemistry,All India Institute Of Medical Sciences,Patna,Bihar,801507.</td>
#                         <td id="T_47658_row3_col1" class="data row3 col1" >440000</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row4" class="row_heading level0 row4" >1909</th>
#                         <td id="T_47658_row4_col0" class="data row4 col0" >Shri Mata Vaishno Devi University,Katra,Jammu And Kashmir,</td>
#                         <td id="T_47658_row4_col1" class="data row4 col1" >443200</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row5" class="row_heading level0 row5" >2009</th>
#                         <td id="T_47658_row5_col0" class="data row5 col0" >Treasurer Society Of India Faridabad 121007 Haryana</td>
#                         <td id="T_47658_row5_col1" class="data row5 col1" >456929</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row6" class="row_heading level0 row6" >642</th>
#                         <td id="T_47658_row6_col0" class="data row6 col0" >Department Of Mathematics,Indian Institute Of Science Education And Research,Pune,Maharashtra,411008.</td>
#                         <td id="T_47658_row6_col1" class="data row6 col1" >484200</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row7" class="row_heading level0 row7" >650</th>
#                         <td id="T_47658_row7_col0" class="data row7 col0" >Department Of Mathematics,Manipal University,Udupi,Karnataka,576104.</td>
#                         <td id="T_47658_row7_col1" class="data row7 col1" >484550</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row8" class="row_heading level0 row8" >634</th>
#                         <td id="T_47658_row8_col0" class="data row8 col0" >Department Of Mathematics,Ambedkar University Of Delhi,Delhi,110075.</td>
#                         <td id="T_47658_row8_col1" class="data row8 col1" >491198</td>
#             </tr>
#             <tr>
#                         <th id="T_47658_level0_row9" class="row_heading level0 row9" >635</th>
#                         <td id="T_47658_row9_col0" class="data row9 col0" >Department Of Mathematics,Amrita School Of Engineering,Bangalore,Karnataka,560035</td>
#                         <td id="T_47658_row9_col1" class="data row9 col1" >500000</td>
#             </tr>
#     </tbody></table>

# %%
cm = sns.light_palette('pink', as_cmap=True)
dt.sort_values(by=['Total Cost'],ascending =False).tail(10).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_a2040_row0_col1{
#             background-color:  #ffc0cb;
#             color:  #000000;
#         }#T_a2040_row1_col1{
#             background-color:  #ffc1cc;
#             color:  #000000;
#         }#T_a2040_row2_col1{
#             background-color:  #ffc2cc;
#             color:  #000000;
#         }#T_a2040_row3_col1{
#             background-color:  #fec2cd;
#             color:  #000000;
#         }#T_a2040_row4_col1{
#             background-color:  #fec6cf;
#             color:  #000000;
#         }#T_a2040_row5_col1{
#             background-color:  #fdc7d1;
#             color:  #000000;
#         }#T_a2040_row6_col1{
#             background-color:  #fdc8d1;
#             color:  #000000;
#         }#T_a2040_row7_col1{
#             background-color:  #fbd1d8;
#             color:  #000000;
#         }#T_a2040_row8_col1{
#             background-color:  #fbd2d9;
#             color:  #000000;
#         }#T_a2040_row9_col1{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }</style><table id="T_a2040_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Institute</th>        <th class="col_heading level0 col1" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2040_level0_row0" class="row_heading level0 row0" >635</th>
#                         <td id="T_a2040_row0_col0" class="data row0 col0" >Department Of Mathematics,Amrita School Of Engineering,Bangalore,Karnataka,560035</td>
#                         <td id="T_a2040_row0_col1" class="data row0 col1" >500000</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row1" class="row_heading level0 row1" >634</th>
#                         <td id="T_a2040_row1_col0" class="data row1 col0" >Department Of Mathematics,Ambedkar University Of Delhi,Delhi,110075.</td>
#                         <td id="T_a2040_row1_col1" class="data row1 col1" >491198</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row2" class="row_heading level0 row2" >650</th>
#                         <td id="T_a2040_row2_col0" class="data row2 col0" >Department Of Mathematics,Manipal University,Udupi,Karnataka,576104.</td>
#                         <td id="T_a2040_row2_col1" class="data row2 col1" >484550</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row3" class="row_heading level0 row3" >642</th>
#                         <td id="T_a2040_row3_col0" class="data row3 col0" >Department Of Mathematics,Indian Institute Of Science Education And Research,Pune,Maharashtra,411008.</td>
#                         <td id="T_a2040_row3_col1" class="data row3 col1" >484200</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row4" class="row_heading level0 row4" >2009</th>
#                         <td id="T_a2040_row4_col0" class="data row4 col0" >Treasurer Society Of India Faridabad 121007 Haryana</td>
#                         <td id="T_a2040_row4_col1" class="data row4 col1" >456929</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row5" class="row_heading level0 row5" >1909</th>
#                         <td id="T_a2040_row5_col0" class="data row5 col0" >Shri Mata Vaishno Devi University,Katra,Jammu And Kashmir,</td>
#                         <td id="T_a2040_row5_col1" class="data row5 col1" >443200</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row6" class="row_heading level0 row6" >376</th>
#                         <td id="T_a2040_row6_col0" class="data row6 col0" >Department Of Biochemistry,All India Institute Of Medical Sciences,Patna,Bihar,801507.</td>
#                         <td id="T_a2040_row6_col1" class="data row6 col1" >440000</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row7" class="row_heading level0 row7" >110</th>
#                         <td id="T_a2040_row7_col0" class="data row7 col0" >Balaji Utthan Sansthan,Patna,Bihar,</td>
#                         <td id="T_a2040_row7_col1" class="data row7 col1" >374000</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row8" class="row_heading level0 row8" >1927</th>
#                         <td id="T_a2040_row8_col0" class="data row8 col0" >Sri Dharmasthala Manjunatheshwara College Of Ayurveda & Hospitals,Udupi,Karnataka,574118</td>
#                         <td id="T_a2040_row8_col1" class="data row8 col1" >365000</td>
#             </tr>
#             <tr>
#                         <th id="T_a2040_level0_row9" class="row_heading level0 row9" >844</th>
#                         <td id="T_a2040_row9_col0" class="data row9 col0" >Dept. Of Biology,Indian Institute Of Science Education And Research,Indian Institute Of Science Education And Research-Pune,Pune,Maharashtra,411008.</td>
#                         <td id="T_a2040_row9_col1" class="data row9 col1" >135000</td>
#             </tr>
#     </tbody></table>

# %%
df.groupby('Institute')['Total Cost'].sum().sort_values(ascending=False).reset_index(name='Total Cost').head(10)
# Out:
#                                                                          Institute  \
# 0                  Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076
# 1                 Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 2                  Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036
# 3                Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016
# 4            Indian Institute Of Technology Kharagpur,Kharagpur,West Bengal,721302
# 5                      Indian Institute Of Technology Delhi,New Delhi,Delhi,110016
# 6                               University Of Hyderabad,Hyderabad,Telangana,500046
# 7                Indian Institute Of Technology Roorkee,Roorkee,Uttarakhand,247667
# 8  Indian Institute Of Science Education And Research Pune,Pune,Maharashtra,411008
# 9             All India Institute Of Medical Sciences,Delhi,New Delhi,Delhi,110029
#
#    Total Cost
# 0   443368513
# 1   426750014
# 2   324963921
# 3   320734536
# 4   237538683
# 5   207385440
# 6   195771145
# 7   184548699
# 8   172814982
# 9   168838175

# %%
# Top n professors getting the most money for the  project
df.groupby('Professor')['Total Cost'].sum().sort_values(ascending=False).reset_index(name='Total Cost').head(10)
# Out:
#                        Professor  Total Cost
# 0                  Dr. G. Mugesh    64003600
# 1                 Dr. Bhas Bapat    57692013
# 2               Dr. Goutam Sheet    43564573
# 3                  Surajit Ghosh    27957120
# 4               Dr. Abhishek Dey    27803900
# 5               Dr. Sayan Bagchi    26300970
# 6            Dr. Prasanta Sanyal    23016800
# 7           Dr. Hanudatta Atreya    22012000
# 8  Prof. Arup Kumar Raychaudhuri    21286400
# 9                 Dr.Saurav Giri    20041820

# %%
# Top n professors handling most number of projects
df.groupby('Professor')['Total Cost'].count().sort_values(ascending=False).reset_index(name='Number of Projects').head(10)
# Out:
#                        Professor  Number of Projects
# 0                 Dr. Anil Kumar                   4
# 1               Dr. Manish Kumar                   3
# 2               Dr. Ashwin Dalal                   3
# 3          Dr. Rajkumar Banerjee                   2
# 4              Dilip Kumar Ghosh                   2
# 5                Dr. Divya Singh                   2
# 6         Dr. Manoj Kumar Sharma                   2
# 7                 Dr. Atul Kumar                   2
# 8  Prof. Rajesh Kumar Srivastava                   2
# 9                Dr. Manoj Kumar                   2

# %% [markdown]
# # Q5
# >**State wise allocation**

# %%
cm = sns.light_palette("blue", as_cmap=True)
df.groupby('State',as_index=False)['Total Cost'].sum().style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_ee0b7_row0_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_ee0b7_row1_col1{
#             background-color:  #d4d4f4;
#             color:  #000000;
#         }#T_ee0b7_row2_col1,#T_ee0b7_row20_col1,#T_ee0b7_row29_col1{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_ee0b7_row3_col1,#T_ee0b7_row8_col1,#T_ee0b7_row15_col1{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_ee0b7_row4_col1,#T_ee0b7_row18_col1{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_ee0b7_row5_col1,#T_ee0b7_row25_col1{
#             background-color:  #c8c8f5;
#             color:  #000000;
#         }#T_ee0b7_row6_col1,#T_ee0b7_row19_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_ee0b7_row7_col1{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_ee0b7_row9_col1{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_ee0b7_row10_col1{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_ee0b7_row11_col1{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_ee0b7_row12_col1{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_ee0b7_row13_col1{
#             background-color:  #0c0cfe;
#             color:  #f1f1f1;
#         }#T_ee0b7_row14_col1{
#             background-color:  #a7a7f7;
#             color:  #000000;
#         }#T_ee0b7_row16_col1{
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }#T_ee0b7_row17_col1{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_ee0b7_row21_col1{
#             background-color:  #1b1bfe;
#             color:  #f1f1f1;
#         }#T_ee0b7_row22_col1{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_ee0b7_row23_col1{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_ee0b7_row24_col1{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_ee0b7_row26_col1{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_ee0b7_row27_col1{
#             background-color:  #0606ff;
#             color:  #f1f1f1;
#         }#T_ee0b7_row28_col1{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_ee0b7_row30_col1{
#             background-color:  #3636fc;
#             color:  #f1f1f1;
#         }#T_ee0b7_row31_col1{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_ee0b7_row32_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_ee0b7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >State</th>        <th class="col_heading level0 col1" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ee0b7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ee0b7_row0_col0" class="data row0 col0" >Andaman And Nicobar Islands</td>
#                         <td id="T_ee0b7_row0_col1" class="data row0 col1" >3332016</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ee0b7_row1_col0" class="data row1 col0" >Andhra Pradesh</td>
#                         <td id="T_ee0b7_row1_col1" class="data row1 col1" >245441503</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ee0b7_row2_col0" class="data row2 col0" >Arunachal Pradesh</td>
#                         <td id="T_ee0b7_row2_col1" class="data row2 col1" >36556413</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ee0b7_row3_col0" class="data row3 col0" >Assam</td>
#                         <td id="T_ee0b7_row3_col1" class="data row3 col1" >536795332</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ee0b7_row4_col0" class="data row4 col0" >Bihar</td>
#                         <td id="T_ee0b7_row4_col1" class="data row4 col1" >76256946</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ee0b7_row5_col0" class="data row5 col0" >Chandigarh</td>
#                         <td id="T_ee0b7_row5_col1" class="data row5 col1" >347105123</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ee0b7_row6_col0" class="data row6 col0" >Chhattisgarh</td>
#                         <td id="T_ee0b7_row6_col1" class="data row6 col1" >57320697</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ee0b7_row7_col0" class="data row7 col0" >Goa</td>
#                         <td id="T_ee0b7_row7_col1" class="data row7 col1" >125255913</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ee0b7_row8_col0" class="data row8 col0" >Gujarat</td>
#                         <td id="T_ee0b7_row8_col1" class="data row8 col1" >535819749</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ee0b7_row9_col0" class="data row9 col0" >Haryana</td>
#                         <td id="T_ee0b7_row9_col1" class="data row9 col1" >190725374</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ee0b7_row10_col0" class="data row10 col0" >Himachal Pradesh</td>
#                         <td id="T_ee0b7_row10_col1" class="data row10 col1" >99123727</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ee0b7_row11_col0" class="data row11 col0" >Jammu And Kashmir</td>
#                         <td id="T_ee0b7_row11_col1" class="data row11 col1" >277546539</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ee0b7_row12_col0" class="data row12 col0" >Jharkhand</td>
#                         <td id="T_ee0b7_row12_col1" class="data row12 col1" >225871584</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ee0b7_row13_col0" class="data row13 col0" >Karnataka</td>
#                         <td id="T_ee0b7_row13_col1" class="data row13 col1" >1908270689</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ee0b7_row14_col0" class="data row14 col0" >Kerala</td>
#                         <td id="T_ee0b7_row14_col1" class="data row14 col1" >618568168</td>
#             </tr>
#             <tr>
#                         <th id="T_ee0b7_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_ee0b7_row15_col0" class="data row15 col0" >Madhya Pradesh</td>
#                         <td id="T_ee0b7_row15_col1" class="data row15 col1" >537888042</td>
#             </tr>
#             <tr>
#                         <t

# %% [markdown]
# # Q6
# >**Sub Area Wise Allocation**

# %%
df.groupby('Sub Area')['Total Cost'].sum()
# Out:
# Sub Area
# Animal Sciences                                               1318311071
# Biomedical And Health Sciences                                 434743361
# Biophysics, Biochemistry, Molecular Biology & Microbiology    1101997758
# Chemical & Environmental Engineering                           593135632
# Civil And Mechanical Engineering                               695682678
# EMR                                                           2582231298
# Earth & Atmospheric Sciences                                   535430142
# Electrical, Electronics & Computer Engineering                1098749324
# Engineering Science                                             12954050
# Health Sciences                                               2289521494
# Inorganic and Physical Chemistry                              2108837131
# Interdiscipilnary Biological Sciences                          347705410
# Materials, Mining & Minerals Engineering                       688509693
# Mathematical Sciences                                          225156619
# Organic Chemistry                                             1406458304
# Physical Sciences                                             2150321752
# Plant Sciences                                                1054902954
# Name: Total Cost, dtype: int64

# %%
# Number of projects
df.groupby('Sub Area')['Total Cost'].count()
# Out:
# Sub Area
# Animal Sciences                                               287
# Biomedical And Health Sciences                                 86
# Biophysics, Biochemistry, Molecular Biology & Microbiology    290
# Chemical & Environmental Engineering                          137
# Civil And Mechanical Engineering                              186
# EMR                                                           641
# Earth & Atmospheric Sciences                                  150
# Electrical, Electronics & Computer Engineering                262
# Engineering Science                                             6
# Health Sciences                                               562
# Inorganic and Physical Chemistry                              475
# Interdiscipilnary Biological Sciences                          71
# Materials, Mining & Minerals Engineering                      145
# Mathematical Sciences                                         138
# Organic Chemistry                                             303
# Physical Sciences                                             630
# Plant Sciences                                                298
# Name: Total Cost, dtype: int64

# %% [markdown]
# # Q7
# >**Number of projects across Discipline and TIER-I institutes**

# %%
pd.crosstab(df['Discipline'], df['TIER-I'],margins=True)
# Out:
# TIER-I                        BITS  CSIR Labs  IISER  IISc  IITs  JNCASR  \
# Discipline
# Chemical Sciences               19         59     71    30   168       7
# EMR                              7         38     34    27   130       6
# Earth & Atmospheric Sciences     2          2      5     3    31       0
# Engineering Sciences            15         25      0    46   361       0
# Life Sciences                   23         76     54    46    85       9
# Mathematical Sciences            5          1      8     4    33       0
# Physical Sciences               20         17     28    16   103       3
# All                             91        218    200   172   911      25
#
# TIER-I                        NITs  Other TIER-I  Others  VIT   All
# Discipline
# Chemical Sciences               26            49     344   11   784
# EMR                             18            15     364    2   641
# Earth & Atmospheric Sciences     2             0     103    2   150
# Engineering Sciences            92             3     179    9   730
# Life Sciences                   15            10    1266   10  1594
# Mathematical Sciences           16             0      69    2   138
# Physical Sciences               34            14     385   10   630
# All                            203            91    2710   46  4667

# %%
dt1 = pd.crosstab(df['Discipline'], df['TIER-I'],margins=False)
# Colour by By Column - Institutes max in green, min in pink 
(dt1.style
     .highlight_min(color='pink')
     .highlight_max(color='lightgreen'))
# Out:
# <style  type="text/css" >
# #T_11086_row0_col2,#T_11086_row0_col7,#T_11086_row0_col9,#T_11086_row3_col3,#T_11086_row3_col4,#T_11086_row3_col6,#T_11086_row4_col0,#T_11086_row4_col1,#T_11086_row4_col3,#T_11086_row4_col5,#T_11086_row4_col8{
#             background-color:  lightgreen;
#         }#T_11086_row1_col9,#T_11086_row2_col0,#T_11086_row2_col3,#T_11086_row2_col4,#T_11086_row2_col5,#T_11086_row2_col6,#T_11086_row2_col7,#T_11086_row2_col9,#T_11086_row3_col2,#T_11086_row3_col5,#T_11086_row5_col1,#T_11086_row5_col5,#T_11086_row5_col7,#T_11086_row5_col8,#T_11086_row5_col9{
#             background-color:  pink;
#         }</style><table id="T_11086_" ><thead>    <tr>        <th class="index_name level0" >TIER-I</th>        <th class="col_heading level0 col0" >BITS</th>        <th class="col_heading level0 col1" >CSIR Labs</th>        <th class="col_heading level0 col2" >IISER</th>        <th class="col_heading level0 col3" >IISc</th>        <th class="col_heading level0 col4" >IITs</th>        <th class="col_heading level0 col5" >JNCASR</th>        <th class="col_heading level0 col6" >NITs</th>        <th class="col_heading level0 col7" >Other TIER-I</th>        <th class="col_heading level0 col8" >Others</th>        <th class="col_heading level0 col9" >VIT</th>    </tr>    <tr>        <th class="index_name level0" >Discipline</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11086_level0_row0" class="row_heading level0 row0" >Chemical Sciences</th>
#                         <td id="T_11086_row0_col0" class="data row0 col0" >19</td>
#                         <td id="T_11086_row0_col1" class="data row0 col1" >59</td>
#                         <td id="T_11086_row0_col2" class="data row0 col2" >71</td>
#                         <td id="T_11086_row0_col3" class="data row0 col3" >30</td>
#                         <td id="T_11086_row0_col4" class="data row0 col4" >168</td>
#                         <td id="T_11086_row0_col5" class="data row0 col5" >7</td>
#                         <td id="T_11086_row0_col6" class="data row0 col6" >26</td>
#                         <td id="T_11086_row0_col7" class="data row0 col7" >49</td>
#                         <td id="T_11086_row0_col8" class="data row0 col8" >344</td>
#                         <td id="T_11086_row0_col9" class="data row0 col9" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_11086_level0_row1" class="row_heading level0 row1" >EMR</th>
#                         <td id="T_11086_row1_col0" class="data row1 col0" >7</td>
#                         <td id="T_11086_row1_col1" class="data row1 col1" >38</td>
#                         <td id="T_11086_row1_col2" class="data row1 col2" >34</td>
#                         <td id="T_11086_row1_col3" class="data row1 col3" >27</td>
#                         <td id="T_11086_row1_col4" class="data row1 col4" >130</td>
#                         <td id="T_11086_row1_col5" class="data row1 col5" >6</td>
#                         <td id="T_11086_row1_col6" class="data row1 col6" >18</td>
#                         <td id="T_11086_row1_col7" class="data row1 col7" >15</td>
#                         <td id="T_11086_row1_col8" class="data row1 col8" >364</td>
#                         <td id="T_11086_row1_col9" class="data row1 col9" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_11086_level0_row2" class="row_heading level0 row2" >Earth & Atmospheric Sciences</th>
#                         <td id="T_11086_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_11086_row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_11086_row2_col2" class="data row2 col2" >5</td>
#                         <td id="T_11086_row2_col3" class="data row2 col3" >3</td>
#                         <td id="T_11086_row2_col4" class="data row2 col4" >31</td>
#                         <td id="T_11086_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_11086_row2_col6" class="data row2 col6" >2</td>
#                         <td id="T_11086_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_11086_row2_col8" class="data row2 col8" >103</td>
#                         <td id="T_11086_row2_col9" class="data row2 col9" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_11086_level0_row3" class="row_heading level0 row3" >Engineering Sciences</th>
#                         <td id="T_11086_row3_col0" class="data row3 col0" >15</td>
#                         <td id="T_11086_row3_col1" class="data row3 col1" >25</td>
#                         <td id="T_11086_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_11086_row3_col3" class="data row3 col3" >46</td>
#                         <td id="T_11086_row3_col4" class="data row3 col4" >361</td>
#                         <td id="T_11086_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_11086_row3_col6" class="data row3 col6" >92</td>
#                         <td id="T_11086_row3_col7" class="data row3 col7" >3</td>
#                         <td id="T_11086_row3_col8" class="data row3 col8" >179</td>
#                         <td id="T_11086_row3_col9" class="data row3 col9" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_11086_level0_row4" class="row_heading level0 row4" >Life Sciences</th>
#                         <td id="T_11086_row4_col0" class="data row4 col0" >23</td>
#                         <td id="T_11086_row4_col1" class="data row4 col1" >76</td>
#                         <td id="T_11086_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_11086_row4_col3" class="data row4 col3" >46</td>
#                         <td id="T_11086_row4_col4" class="data row4 col4" >85</td>
#                         <td id="T_11086_row4_col5" class="data row4 col5" >9</td>
#                         <td id="T_11086_row4_col6" class="data row4 col6" >15</td>
#                         <td id="T_11086_row4_col7" class="data row4 col7" >10</td>
#                         <td id="T_11086_row4_col8" class="data row4 col8" >1266</td>
#                         <td id="T_11086_row4_col9" class="data row4 col9" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_11086_level0_row5" class="row_heading level0 row5" >Mathematical Sciences</th>
#                         <td id="T_11086_row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_11086_row5_col1" class="data row5 col1" >1</td>
#                         <td id="T_11086_row5_col2" class="data row5 col2" >8</td>
#                         <td id="T_11086_row5_col3" class="data row5 col3" >4</td>
#                         <td id="T_11086_row5_col4" class="data row5 col4" >33</td>
#                         <td id="T_11086_row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_11086_row5_col6" class="data row5 col6" >16</td>
#                         <td id="T_11086_row5_col7" class="data row5 col7" >0</td>
#                         <td id="T_11086_row5_col8" class="data row5 col8" >69</td>
#                         <td id="T_11086_row5_col9" class="data row5 col9" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_11086_level0_row6" class="row_heading level0 row6" >Physical Sciences</th>
#                         <td id="T_11086_row6_col0" class="data row6 col0" >20</td>
#                         <td id="T_11086_row6_col1" class="data row6 col1" >17</td>
#                         <td id="T_11086_row6_col2" class="data row6 col2" >28</td>
#                         <td id="T_11086_row6_col3" class="data row6 col3" >16</td>

# %%
# By Row 
# Colour by By Row - Discipline max in blue, min in pink
(dt1.drop('Others', axis=1).style
     .highlight_min(axis=1,color='pink')
     .highlight_max(axis=1,color='lightblue'))
# Out:
# <style  type="text/css" >
# #T_951c3_row0_col4,#T_951c3_row1_col4,#T_951c3_row2_col4,#T_951c3_row3_col4,#T_951c3_row4_col4,#T_951c3_row5_col4,#T_951c3_row6_col4{
#             background-color:  lightblue;
#         }#T_951c3_row0_col5,#T_951c3_row1_col8,#T_951c3_row2_col5,#T_951c3_row2_col7,#T_951c3_row3_col2,#T_951c3_row3_col5,#T_951c3_row4_col5,#T_951c3_row5_col5,#T_951c3_row5_col7,#T_951c3_row6_col5{
#             background-color:  pink;
#         }</style><table id="T_951c3_" ><thead>    <tr>        <th class="index_name level0" >TIER-I</th>        <th class="col_heading level0 col0" >BITS</th>        <th class="col_heading level0 col1" >CSIR Labs</th>        <th class="col_heading level0 col2" >IISER</th>        <th class="col_heading level0 col3" >IISc</th>        <th class="col_heading level0 col4" >IITs</th>        <th class="col_heading level0 col5" >JNCASR</th>        <th class="col_heading level0 col6" >NITs</th>        <th class="col_heading level0 col7" >Other TIER-I</th>        <th class="col_heading level0 col8" >VIT</th>    </tr>    <tr>        <th class="index_name level0" >Discipline</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_951c3_level0_row0" class="row_heading level0 row0" >Chemical Sciences</th>
#                         <td id="T_951c3_row0_col0" class="data row0 col0" >19</td>
#                         <td id="T_951c3_row0_col1" class="data row0 col1" >59</td>
#                         <td id="T_951c3_row0_col2" class="data row0 col2" >71</td>
#                         <td id="T_951c3_row0_col3" class="data row0 col3" >30</td>
#                         <td id="T_951c3_row0_col4" class="data row0 col4" >168</td>
#                         <td id="T_951c3_row0_col5" class="data row0 col5" >7</td>
#                         <td id="T_951c3_row0_col6" class="data row0 col6" >26</td>
#                         <td id="T_951c3_row0_col7" class="data row0 col7" >49</td>
#                         <td id="T_951c3_row0_col8" class="data row0 col8" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_951c3_level0_row1" class="row_heading level0 row1" >EMR</th>
#                         <td id="T_951c3_row1_col0" class="data row1 col0" >7</td>
#                         <td id="T_951c3_row1_col1" class="data row1 col1" >38</td>
#                         <td id="T_951c3_row1_col2" class="data row1 col2" >34</td>
#                         <td id="T_951c3_row1_col3" class="data row1 col3" >27</td>
#                         <td id="T_951c3_row1_col4" class="data row1 col4" >130</td>
#                         <td id="T_951c3_row1_col5" class="data row1 col5" >6</td>
#                         <td id="T_951c3_row1_col6" class="data row1 col6" >18</td>
#                         <td id="T_951c3_row1_col7" class="data row1 col7" >15</td>
#                         <td id="T_951c3_row1_col8" class="data row1 col8" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_951c3_level0_row2" class="row_heading level0 row2" >Earth & Atmospheric Sciences</th>
#                         <td id="T_951c3_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_951c3_row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_951c3_row2_col2" class="data row2 col2" >5</td>
#                         <td id="T_951c3_row2_col3" class="data row2 col3" >3</td>
#                         <td id="T_951c3_row2_col4" class="data row2 col4" >31</td>
#                         <td id="T_951c3_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_951c3_row2_col6" class="data row2 col6" >2</td>
#                         <td id="T_951c3_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_951c3_row2_col8" class="data row2 col8" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_951c3_level0_row3" class="row_heading level0 row3" >Engineering Sciences</th>
#                         <td id="T_951c3_row3_col0" class="data row3 col0" >15</td>
#                         <td id="T_951c3_row3_col1" class="data row3 col1" >25</td>
#                         <td id="T_951c3_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_951c3_row3_col3" class="data row3 col3" >46</td>
#                         <td id="T_951c3_row3_col4" class="data row3 col4" >361</td>
#                         <td id="T_951c3_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_951c3_row3_col6" class="data row3 col6" >92</td>
#                         <td id="T_951c3_row3_col7" class="data row3 col7" >3</td>
#                         <td id="T_951c3_row3_col8" class="data row3 col8" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_951c3_level0_row4" class="row_heading level0 row4" >Life Sciences</th>
#                         <td id="T_951c3_row4_col0" class="data row4 col0" >23</td>
#                         <td id="T_951c3_row4_col1" class="data row4 col1" >76</td>
#                         <td id="T_951c3_row4_col2" class="data row4 col2" >54</td>
#                         <td id="T_951c3_row4_col3" class="data row4 col3" >46</td>
#                         <td id="T_951c3_row4_col4" class="data row4 col4" >85</td>
#                         <td id="T_951c3_row4_col5" class="data row4 col5" >9</td>
#                         <td id="T_951c3_row4_col6" class="data row4 col6" >15</td>
#                         <td id="T_951c3_row4_col7" class="data row4 col7" >10</td>
#                         <td id="T_951c3_row4_col8" class="data row4 col8" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_951c3_level0_row5" class="row_heading level0 row5" >Mathematical Sciences</th>
#                         <td id="T_951c3_row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_951c3_row5_col1" class="data row5 col1" >1</td>
#                         <td id="T_951c3_row5_col2" class="data row5 col2" >8</td>
#                         <td id="T_951c3_row5_col3" class="data row5 col3" >4</td>
#                         <td id="T_951c3_row5_col4" class="data row5 col4" >33</td>
#                         <td id="T_951c3_row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_951c3_row5_col6" class="data row5 col6" >16</td>
#                         <td id="T_951c3_row5_col7" class="data row5 col7" >0</td>
#                         <td id="T_951c3_row5_col8" class="data row5 col8" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_951c3_level0_row6" class="row_heading level0 row6" >Physical Sciences</th>
#                         <td id="T_951c3_row6_col0" class="data row6 col0" >20</td>
#                         <td id="T_951c3_row6_col1" class="data row6 col1" >17</td>
#                         <td id="T_951c3_row6_col2" class="data row6 col2" >28</td>
#                         <td id="T_951c3_row6_col3" class="data row6 col3" >16</td>
#                         <td id="T_951c3_row6_col4" class="data row6 col4" >103</td>
#                         <td id="T_951c3_row6_col5" class="data row6 col5" >3</td>
#                         <td id="T_951c3_row6_col6" class="data row6 col6" >34</td>
#                         <td id="T_951c3_row6_col7" class="data row6 col7" >14</td>
#                         <td id="T_951c3_row6_col8" class="data row6 col8" >10</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Q8
# >**Get Top n Per group**

# %%
# Get Top 5 Institute per year

# %%
# Aggregate by Yr and Institute
dt = df.groupby(['Year', 'Institute'],as_index=False)['Total Cost'].sum()
# Sort
dt_sorted = dt.groupby(['Year']).apply(lambda x: x.sort_values(['Total Cost'],ascending = False)).reset_index(drop = True)

# %%
# Get top3 Institute per year
cm = sns.light_palette("lightblue", as_cmap=True)
dt_sorted.groupby(['Year']).head(3).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_d05b5_row0_col2{
#             background-color:  #e3ecef;
#             color:  #000000;
#         }#T_d05b5_row1_col2{
#             background-color:  #eaeff1;
#             color:  #000000;
#         }#T_d05b5_row2_col2,#T_d05b5_row5_col2{
#             background-color:  #eff1f2;
#             color:  #000000;
#         }#T_d05b5_row3_col2{
#             background-color:  #dfebef;
#             color:  #000000;
#         }#T_d05b5_row4_col2{
#             background-color:  #e9eff0;
#             color:  #000000;
#         }#T_d05b5_row6_col2{
#             background-color:  #d1e5ec;
#             color:  #000000;
#         }#T_d05b5_row7_col2{
#             background-color:  #d9e9ee;
#             color:  #000000;
#         }#T_d05b5_row8_col2{
#             background-color:  #e2ecef;
#             color:  #000000;
#         }#T_d05b5_row9_col2{
#             background-color:  #b8dce8;
#             color:  #000000;
#         }#T_d05b5_row10_col2{
#             background-color:  #bddee9;
#             color:  #000000;
#         }#T_d05b5_row11_col2{
#             background-color:  #d8e8ee;
#             color:  #000000;
#         }#T_d05b5_row12_col2{
#             background-color:  #add8e6;
#             color:  #000000;
#         }#T_d05b5_row13_col2{
#             background-color:  #b2dae7;
#             color:  #000000;
#         }#T_d05b5_row14_col2{
#             background-color:  #badde8;
#             color:  #000000;
#         }</style><table id="T_d05b5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Institute</th>        <th class="col_heading level0 col2" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d05b5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d05b5_row0_col0" class="data row0 col0" >2015-16</td>
#                         <td id="T_d05b5_row0_col1" class="data row0 col1" >Indian Institute Of Science Bangalore 560012 Karnataka</td>
#                         <td id="T_d05b5_row0_col2" class="data row0 col2" >71309400</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d05b5_row1_col0" class="data row1 col0" >2015-16</td>
#                         <td id="T_d05b5_row1_col1" class="data row1 col1" >Indian Institute Of Science Bangalore 560012Karnataka</td>
#                         <td id="T_d05b5_row1_col2" class="data row1 col2" >54990472</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d05b5_row2_col0" class="data row2 col0" >2015-16</td>
#                         <td id="T_d05b5_row2_col1" class="data row2 col1" >Banaras Hindu University Varanasi 221005Uttar Pradesh</td>
#                         <td id="T_d05b5_row2_col2" class="data row2 col2" >42981752</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row3" class="row_heading level0 row3" >394</th>
#                         <td id="T_d05b5_row3_col0" class="data row3 col0" >2016-17</td>
#                         <td id="T_d05b5_row3_col1" class="data row3 col1" >Indian Institute Of Science,Bangalore,Karnataka,560012.</td>
#                         <td id="T_d05b5_row3_col2" class="data row3 col2" >82442252</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row4" class="row_heading level0 row4" >395</th>
#                         <td id="T_d05b5_row4_col0" class="data row4 col0" >2016-17</td>
#                         <td id="T_d05b5_row4_col1" class="data row4 col1" >Dept. Of Physics,Iiser- Pune,Pune,Maharashtra,411008.</td>
#                         <td id="T_d05b5_row4_col2" class="data row4 col2" >57692013</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row5" class="row_heading level0 row5" >396</th>
#                         <td id="T_d05b5_row5_col0" class="data row5 col0" >2016-17</td>
#                         <td id="T_d05b5_row5_col1" class="data row5 col1" >Department Of Physics,Indian Institute Of Science Education And Research,Mohali,Punjab,140306.</td>
#                         <td id="T_d05b5_row5_col2" class="data row5 col2" >43564573</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row6" class="row_heading level0 row6" >1246</th>
#                         <td id="T_d05b5_row6_col0" class="data row6 col0" >2017-18</td>
#                         <td id="T_d05b5_row6_col1" class="data row6 col1" >Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016</td>
#                         <td id="T_d05b5_row6_col2" class="data row6 col2" >114841926</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row7" class="row_heading level0 row7" >1247</th>
#                         <td id="T_d05b5_row7_col0" class="data row7 col0" >2017-18</td>
#                         <td id="T_d05b5_row7_col1" class="data row7 col1" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_d05b5_row7_col2" class="data row7 col2" >94447693</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row8" class="row_heading level0 row8" >1248</th>
#                         <td id="T_d05b5_row8_col0" class="data row8 col0" >2017-18</td>
#                         <td id="T_d05b5_row8_col1" class="data row8 col1" >Indian Institute Of Science,Banglore,Bangalore,Karnataka,560012</td>
#                         <td id="T_d05b5_row8_col2" class="data row8 col2" >74490328</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row9" class="row_heading level0 row9" >1560</th>
#                         <td id="T_d05b5_row9_col0" class="data row9 col0" >2018-19</td>
#                         <td id="T_d05b5_row9_col1" class="data row9 col1" >Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012</td>
#                         <td id="T_d05b5_row9_col2" class="data row9 col2" >173103733</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row10" class="row_heading level0 row10" >1561</th>
#                         <td id="T_d05b5_row10_col0" class="data row10 col0" >2018-19</td>
#                         <td id="T_d05b5_row10_col1" class="data row10 col1" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_d05b5_row10_col2" class="data row10 col2" >161571780</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row11" class="row_heading level0 row11" >1562</th>
#                         <td id="T_d05b5_row11_col0" class="data row11 col0" >2018-19</td>
#                         <td id="T_d05b5_row11_col1" class="data row11 col1" >Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036</td>
#                         <td id="T_d05b5_row11_col2" class="data row11 col2" >97650866</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row12" class="row_heading level0 row12" >2022</th>
#                         <td id="T_d05b5_row12_col0" class="data row12 col0" >2019-20</td>
#                         <td id="T_d05b5_row12_col1" class="data row12 col1" >Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012</td>
#                         <td id="T_d05b5_row12_col2" class="data row12 col2" >198737416</td>
#             </tr>
#             <tr>
#                         <th id="T_d05b5_level0_row13" class="row_heading level0 row13" >2023</th>
#                         <td id="T_d05b5_row13_col0" class="data row13 col0" >2019-20</td>
#                         <td id="T_d05b5_row13_col1" class="data row13 col1" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_d05b5_row13_col2" class="da

# %%
# Get top 3 per Year  
dt_sorted.groupby(['Year'],as_index=False).nth((0,1,2)).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_9a9e3_row0_col2{
#             background-color:  #e3ecef;
#             color:  #000000;
#         }#T_9a9e3_row1_col2{
#             background-color:  #eaeff1;
#             color:  #000000;
#         }#T_9a9e3_row2_col2,#T_9a9e3_row5_col2{
#             background-color:  #eff1f2;
#             color:  #000000;
#         }#T_9a9e3_row3_col2{
#             background-color:  #dfebef;
#             color:  #000000;
#         }#T_9a9e3_row4_col2{
#             background-color:  #e9eff0;
#             color:  #000000;
#         }#T_9a9e3_row6_col2{
#             background-color:  #d1e5ec;
#             color:  #000000;
#         }#T_9a9e3_row7_col2{
#             background-color:  #d9e9ee;
#             color:  #000000;
#         }#T_9a9e3_row8_col2{
#             background-color:  #e2ecef;
#             color:  #000000;
#         }#T_9a9e3_row9_col2{
#             background-color:  #b8dce8;
#             color:  #000000;
#         }#T_9a9e3_row10_col2{
#             background-color:  #bddee9;
#             color:  #000000;
#         }#T_9a9e3_row11_col2{
#             background-color:  #d8e8ee;
#             color:  #000000;
#         }#T_9a9e3_row12_col2{
#             background-color:  #add8e6;
#             color:  #000000;
#         }#T_9a9e3_row13_col2{
#             background-color:  #b2dae7;
#             color:  #000000;
#         }#T_9a9e3_row14_col2{
#             background-color:  #badde8;
#             color:  #000000;
#         }</style><table id="T_9a9e3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Institute</th>        <th class="col_heading level0 col2" >Total Cost</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a9e3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9a9e3_row0_col0" class="data row0 col0" >2015-16</td>
#                         <td id="T_9a9e3_row0_col1" class="data row0 col1" >Indian Institute Of Science Bangalore 560012 Karnataka</td>
#                         <td id="T_9a9e3_row0_col2" class="data row0 col2" >71309400</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9a9e3_row1_col0" class="data row1 col0" >2015-16</td>
#                         <td id="T_9a9e3_row1_col1" class="data row1 col1" >Indian Institute Of Science Bangalore 560012Karnataka</td>
#                         <td id="T_9a9e3_row1_col2" class="data row1 col2" >54990472</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9a9e3_row2_col0" class="data row2 col0" >2015-16</td>
#                         <td id="T_9a9e3_row2_col1" class="data row2 col1" >Banaras Hindu University Varanasi 221005Uttar Pradesh</td>
#                         <td id="T_9a9e3_row2_col2" class="data row2 col2" >42981752</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row3" class="row_heading level0 row3" >394</th>
#                         <td id="T_9a9e3_row3_col0" class="data row3 col0" >2016-17</td>
#                         <td id="T_9a9e3_row3_col1" class="data row3 col1" >Indian Institute Of Science,Bangalore,Karnataka,560012.</td>
#                         <td id="T_9a9e3_row3_col2" class="data row3 col2" >82442252</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row4" class="row_heading level0 row4" >395</th>
#                         <td id="T_9a9e3_row4_col0" class="data row4 col0" >2016-17</td>
#                         <td id="T_9a9e3_row4_col1" class="data row4 col1" >Dept. Of Physics,Iiser- Pune,Pune,Maharashtra,411008.</td>
#                         <td id="T_9a9e3_row4_col2" class="data row4 col2" >57692013</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row5" class="row_heading level0 row5" >396</th>
#                         <td id="T_9a9e3_row5_col0" class="data row5 col0" >2016-17</td>
#                         <td id="T_9a9e3_row5_col1" class="data row5 col1" >Department Of Physics,Indian Institute Of Science Education And Research,Mohali,Punjab,140306.</td>
#                         <td id="T_9a9e3_row5_col2" class="data row5 col2" >43564573</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row6" class="row_heading level0 row6" >1246</th>
#                         <td id="T_9a9e3_row6_col0" class="data row6 col0" >2017-18</td>
#                         <td id="T_9a9e3_row6_col1" class="data row6 col1" >Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016</td>
#                         <td id="T_9a9e3_row6_col2" class="data row6 col2" >114841926</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row7" class="row_heading level0 row7" >1247</th>
#                         <td id="T_9a9e3_row7_col0" class="data row7 col0" >2017-18</td>
#                         <td id="T_9a9e3_row7_col1" class="data row7 col1" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_9a9e3_row7_col2" class="data row7 col2" >94447693</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row8" class="row_heading level0 row8" >1248</th>
#                         <td id="T_9a9e3_row8_col0" class="data row8 col0" >2017-18</td>
#                         <td id="T_9a9e3_row8_col1" class="data row8 col1" >Indian Institute Of Science,Banglore,Bangalore,Karnataka,560012</td>
#                         <td id="T_9a9e3_row8_col2" class="data row8 col2" >74490328</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row9" class="row_heading level0 row9" >1560</th>
#                         <td id="T_9a9e3_row9_col0" class="data row9 col0" >2018-19</td>
#                         <td id="T_9a9e3_row9_col1" class="data row9 col1" >Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012</td>
#                         <td id="T_9a9e3_row9_col2" class="data row9 col2" >173103733</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row10" class="row_heading level0 row10" >1561</th>
#                         <td id="T_9a9e3_row10_col0" class="data row10 col0" >2018-19</td>
#                         <td id="T_9a9e3_row10_col1" class="data row10 col1" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_9a9e3_row10_col2" class="data row10 col2" >161571780</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row11" class="row_heading level0 row11" >1562</th>
#                         <td id="T_9a9e3_row11_col0" class="data row11 col0" >2018-19</td>
#                         <td id="T_9a9e3_row11_col1" class="data row11 col1" >Indian Institute Of Technology Madras,Chennai,Tamil Nadu,600036</td>
#                         <td id="T_9a9e3_row11_col2" class="data row11 col2" >97650866</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row12" class="row_heading level0 row12" >2022</th>
#                         <td id="T_9a9e3_row12_col0" class="data row12 col0" >2019-20</td>
#                         <td id="T_9a9e3_row12_col1" class="data row12 col1" >Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012</td>
#                         <td id="T_9a9e3_row12_col2" class="data row12 col2" >198737416</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e3_level0_row13" class="row_heading level0 row13" >2023</th>
#                         <td id="T_9a9e3_row13_col0" class="data row13 col0" >2019-20</td>
#                         <td id="T_9a9e3_row13_col1" class="data row13 col1" >Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076</td>
#                         <td id="T_9a9e3_row13_col2" class="da

# %%
# Get the Top Institute per year
dt_sorted.groupby(['Year']).first()
# Out:
#                                                                  Institute  \
# Year
# 2015-16             Indian Institute Of Science Bangalore 560012 Karnataka
# 2016-17            Indian Institute Of Science,Bangalore,Karnataka,560012.
# 2017-18  Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016
# 2018-19   Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 2019-20   Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
#
#          Total Cost
# Year
# 2015-16    71309400
# 2016-17    82442252
# 2017-18   114841926
# 2018-19   173103733
# 2019-20   198737416

# %%
# Get the Top Institute per year
dt_sorted.groupby(['Year']).nth(0)
# Out:
#                                                                  Institute  \
# Year
# 2015-16             Indian Institute Of Science Bangalore 560012 Karnataka
# 2016-17            Indian Institute Of Science,Bangalore,Karnataka,560012.
# 2017-18  Indian Institute Of Technology Kanpur,Kanpur,Uttar Pradesh,208016
# 2018-19   Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
# 2019-20   Indian Institute Of Science,Bangalore,Bangalore,Karnataka,560012
#
#          Total Cost
# Year
# 2015-16    71309400
# 2016-17    82442252
# 2017-18   114841926
# 2018-19   173103733
# 2019-20   198737416

# %%
# The second highest for the year
dt_sorted.groupby(['Year']).nth(1)
# Out:
#                                                                Institute  \
# Year
# 2015-16            Indian Institute Of Science Bangalore 560012Karnataka
# 2016-17            Dept. Of Physics,Iiser- Pune,Pune,Maharashtra,411008.
# 2017-18  Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076
# 2018-19  Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076
# 2019-20  Indian Institute Of Technology Bombay,Mumbai,Maharashtra,400076
#
#          Total Cost
# Year
# 2015-16    54990472
# 2016-17    57692013
# 2017-18    94447693
# 2018-19   161571780
# 2019-20   187349040
