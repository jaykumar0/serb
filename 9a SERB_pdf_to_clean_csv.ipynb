# %%
import pandas as pd
import numpy as np
import tabula

# %%
# Function to clean the pdf 
def func_clean_df(df):
    # The column Total Cost is the starting point for the new row...not the serial no...
    # get a new serial no ...increment if amount is present, else same 
    # so that we can group them into one row....
    newSrl = []
    srl = 0
    for i in range(0,len(df)):
        if pd.isna(df.loc[i,'Total Cost']) : # & pd.notna(df_2018_19.loc[i+1,'Total Cost']) :
            newSrl.append(srl)
        else:
            srl = srl + 1
            newSrl.append(srl)
    # Create a new column
    df['NewSrl'] = newSrl
    # Fill na with  0, so that can be summed in group
    df['Total Cost'] = df['Total Cost'].fillna(0)
    df = df.astype({'Total Cost': 'int32'})
    # Group and join the columns
    df1 = df.fillna('').groupby('NewSrl',as_index=False).agg(
        **{
            'Discipline': pd.NamedAgg('Discipline', ' '.join),
            'Sub Area': pd.NamedAgg('Sub Area', ' '.join),
            'Title': pd.NamedAgg('Title', ' '.join),
            'PI Details': pd.NamedAgg('PI Details', ' '.join),
            'Total Cost': pd.NamedAgg('Total Cost',sum)
          }   
          )    
    return(df1)

# %%
# Function to clean the pdf for 2015-16 as the column names and information is different
def func_clean_df2(df):
    # The column Total Cost is the starting point for the new row...not the serial no...
    # get a new serial no ...increment if amount is present, else same 
    # so that we can group them into one row....
    newSrl = []
    srl = 0
    for i in range(0,len(df)):
        if pd.isna(df.loc[i,'Total Cost']) : # & pd.notna(df_2018_19.loc[i+1,'Total Cost']) :
            newSrl.append(srl)
        else:
            srl = srl + 1
            newSrl.append(srl)
    # Create a new column
    df['NewSrl'] = newSrl
    # Fill na with  0, so that can be summed in group
    df['Total Cost'] = df['Total Cost'].fillna(0)
    df = df.astype({'Total Cost': 'int32'})
    # Group and join the columns
    df1 = df.fillna('').groupby('NewSrl',as_index=False).agg(
        **{
            'Scheme': pd.NamedAgg('Scheme', ' '.join),
            'Title': pd.NamedAgg('Title', ' '.join),
            'PI Name': pd.NamedAgg('PI Name', ' '.join),
            'Institute & Address': pd.NamedAgg('Institute & Address', ' '.join),
            'Total Cost': pd.NamedAgg('Total Cost',sum)
          }   
          )    
    return(df1)

# %% [markdown]
# # 1.  Process 2015-16 - pdf to csv

# %%
# read as one table, takes time 
dfs = tabula.read_pdf('data/Sanctioned Project EMR 2015-16.pdf',multiple_tables=False, pages="all")

df = dfs[0]
df.shape
# Out:
# (2608, 6)

# %%
df.columns
# Out:
# Index(['S.No.', 'Scheme', 'Title', 'PI Name', 'Institute & Address',
#        'Total Cost'],
#       dtype='object')

# %%
df_1516 = func_clean_df2(df)
df_1516.shape
# Out:
# (641, 6)

# %%
df_1516.head()
# Out:
#    NewSrl Scheme                                              Title  \
# 0       1    EMR  Development of Sugar amino\racid derived pepti...
# 1       2    EMR  Development of Sugar amino\racid derived pepti...
# 2       3    EMR  Band gap tuning of transtion\rmetal oxides (Zn...
# 3       4    EMR  Investigation of physical aging in\rHigh Tg po...
# 4       5    EMR  Investigation of ultiferroic\rproperties of re...
#
#                           PI Name  \
# 0      Dr.Ravi Shankar\rAmpapathi
# 1  Prof.Tushar Kanti\rChakraborty
# 2               Dr.SanjibKarmakar
# 3              Dr.Asmita Sengupta
# 4             Dr.I.B.Shameem Banu
#
#                                  Institute & Address  Total Cost
# 0  Central Drug Research\rInstitute Lucknow 22603...     2660000
# 1  Indian Institute of Science\rBangalore 560012\...     6384000
# 2          Gauhati University\rGuwahati 781014 Assam     1588800
# 3  Visva -Bharati Central\rUniversity Bolpur\rSan...     1553520
# 4  B.S.Abdur Rahman\rUniversity Chennai 600048\rT...     2355300

# %% [markdown]
# # 2. Process 2016-17 - pdf to csv

# %%
# read as one table, takes time 
dfs = tabula.read_pdf('data/EMR 2016-17.pdf',multiple_tables=False, pages="all")
df = dfs[0]
df.shape
# Out:
# (1750, 10)

# %%
# remove first 4 rows and last 4 columns
df = df.iloc[4:].copy()
# drop the nan columns
df.drop(['Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9'], axis = 1,inplace=True)
# rename columns
df.columns = ['S. No.', 'Discipline', 'Sub Area', 'Title', 'PI Details', 'Total Cost']
# re index after droppng rows
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#   S. No.          Discipline                          Sub Area  \
# 0     1.  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 1     2.  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 2     3.  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 3     4.  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 4     5.  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
#
#                                                Title  \
# 0  Investigation on the effect of ionic\rliquids ...
# 1  Optical And Electrochemical Sensors\rbased on ...
# 2  A Concerted drive towards ambient\rpressure sy...
# 3  Estimation of nanoparticles (Toxic\rmetals) Fr...
# 4  Investigation on an Electrochemical\rsystem co...
#
#                                           PI Details Total Cost
# 0  Dr. Harsh Kumar Manchanda,\rDepartment of Chem...    3300000
# 1  Dr. Shweta Rana,\rDepartment of Chemistry,\rPa...    3025000
# 2  Dr.Md. Motin Seikh,\rDepartment of Chemistry,\...    3739560
# 3  Dr. Kalpana Kumari,\rDepartment of Chemistry,\...    1900800
# 4  Dr. Anudeep Kumar Narula,\rGuru Gobind Singh I...    3185600

# %%
df_1617 = func_clean_df(df)
df_1617.shape
# Out:
# (952, 6)

# %%
df_1617.head()
# Out:
#    NewSrl          Discipline                          Sub Area  \
# 0       1  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 1       2  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 2       3  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 3       4  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 4       5  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
#
#                                                Title  \
# 0  Investigation on the effect of ionic\rliquids ...
# 1  Optical And Electrochemical Sensors\rbased on ...
# 2  A Concerted drive towards ambient\rpressure sy...
# 3  Estimation of nanoparticles (Toxic\rmetals) Fr...
# 4  Investigation on an Electrochemical\rsystem co...
#
#                                           PI Details  Total Cost
# 0  Dr. Harsh Kumar Manchanda,\rDepartment of Chem...     3300000
# 1  Dr. Shweta Rana,\rDepartment of Chemistry,\rPa...     3025000
# 2  Dr.Md. Motin Seikh,\rDepartment of Chemistry,\...     3739560
# 3  Dr. Kalpana Kumari,\rDepartment of Chemistry,\...     1900800
# 4  Dr. Anudeep Kumar Narula,\rGuru Gobind Singh I...     3185600

# %% [markdown]
# # 3. Process 2017-18 - pdf to csv

# %%
dfs = tabula.read_pdf('data/List of EMR projects funded by SERB during 2017-18.pdf',multiple_tables=False, pages="all")
df = dfs[0]
df.shape
# Out:
# Got stderr: Feb 15, 2022 6:34:18 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:18 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:20 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:21 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:25 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:26 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:27 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:28 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:29 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:41 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:42 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Feb 15, 2022 6:34:44 PM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# (3947, 6)

# %%
# first row is column names
# and then drop first row
df.columns = df.iloc[0]

df.drop(labels=0, axis=0,inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# 0 S. No         Discipline                            Sub Area  \
# 0     1  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 1     2  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 2     3  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 3     4  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 4     5  Chemical\rScience  Inorganic and\rPhysical\rChemistry
#
# 0                                              Title  \
# 0  Surface anchored metal organic\rthin film devices
# 1  Design of diagnostic tools to\rmonitor certain...
# 2  Coordination complexes of\rorganic radicals sy...
# 3  Exploration of key photinduced\rdyanmics in in...
# 4  Metal Complexes based probes\rfor arylamine mo...
#
# 0                                         PI Details Total Cost
# 0  Dr. Nirmalya Ballav,\rIndian institute of\rSci...    6803280
# 1  Dr. Meenakshi Singh,\rBanaras Hindu\rUniversit...    4387810
# 2  Dr. Prasanta Ghosh,\rRamakrishna Mission\rResi...    4163280
# 3  Dr. Samir Kumar Pal, S\rN Bose National Centre...    1998000
# 4  Dr. Dr. Vaidyanathan\rGanesan, Central Leather...    2286145

# %%
df_1718 = func_clean_df(df)
df_1718.shape
# Out:
# (757, 6)

# %%
df_1718.head()
# Out:
#    NewSrl         Discipline                            Sub Area  \
# 0       1  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 1       2  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 2       3  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 3       4  Chemical\rScience  Inorganic and\rPhysical\rChemistry
# 4       5  Chemical\rScience  Inorganic and\rPhysical\rChemistry
#
#                                                Title  \
# 0  Surface anchored metal organic\rthin film devices
# 1  Design of diagnostic tools to\rmonitor certain...
# 2  Coordination complexes of\rorganic radicals sy...
# 3  Exploration of key photinduced\rdyanmics in in...
# 4  Metal Complexes based probes\rfor arylamine mo...
#
#                                           PI Details  Total Cost
# 0  Dr. Nirmalya Ballav,\rIndian institute of\rSci...     6803280
# 1  Dr. Meenakshi Singh,\rBanaras Hindu\rUniversit...     4387810
# 2  Dr. Prasanta Ghosh,\rRamakrishna Mission\rResi...     4163280
# 3  Dr. Samir Kumar Pal, S\rN Bose National Centre...     1998000
# 4  Dr. Dr. Vaidyanathan\rGanesan, Central Leather...     2286145

# %% [markdown]
# # 4. Process 2018-19 - pdf to csv

# %%
# read as one table, takes time 
dfs = tabula.read_pdf('data/CRG 2018-19.pdf',multiple_tables=False, pages="all")

df = dfs[0]
df.shape
# Out:
# (10621, 6)

# %%
# first row is column names
# and then drop first row
df.columns = df.iloc[0]

df.drop(labels=0, axis=0,inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# 0 S. No.          Discipline                            Sub Area  \
# 0      1  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 1      2  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 2      3  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 3      4  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 4      5  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
#
# 0                                              Title  \
# 0  Photothermal Properties of\rAnisotropic Metal\...
# 1  Highly Selective Ring-Opening\rPolymerization ...
# 2  Synthesis, Characterization And\rCatalytic App...
# 3  Integrated Gravity Flow Water\rFiltration Syst...
# 4  Novel Electrode Materials For\rReversible Alka...
#
# 0                                         PI Details Total Cost
# 0  Dr. Sujit Kumar Ghosh,\rAssam University,\rSil...    2562560
# 1  Dr. Tarun Kanti Panda,\rIndian Institute of\rT...    6508480
# 2  Dr. Firasat Hussain,\rUniversity of Delhi,\rDe...    3520000
# 3  Dr. Raj Kishore Patel,\rNational Institute of\...    3658600
# 4  Dr. Preetam Singh,\rIndian Institute of\rTechn...    3665245

# %%
df_1819 = func_clean_df(df)
df_1819.shape
# Out:
# (1276, 6)

# %%
df_1819.head()
# Out:
#    NewSrl          Discipline                            Sub Area  \
# 0       1  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 1       2  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 2       3  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 3       4  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 4       5  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
#
#                                                Title  \
# 0  Photothermal Properties of\rAnisotropic Metal\...
# 1  Highly Selective Ring-Opening\rPolymerization ...
# 2  Synthesis, Characterization And\rCatalytic App...
# 3  Integrated Gravity Flow Water\rFiltration Syst...
# 4  Novel Electrode Materials For\rReversible Alka...
#
#                                           PI Details  Total Cost
# 0  Dr. Sujit Kumar Ghosh,\rAssam University,\rSil...     2562560
# 1  Dr. Tarun Kanti Panda,\rIndian Institute of\rT...     6508480
# 2  Dr. Firasat Hussain,\rUniversity of Delhi,\rDe...     3520000
# 3  Dr. Raj Kishore Patel,\rNational Institute of\...     3658600
# 4  Dr. Preetam Singh,\rIndian Institute of\rTechn...     3665245

# %% [markdown]
# # 5. Process 2019-20 - pdf to csv

# %%
# read as one table, takes time 
dfs = tabula.read_pdf('data/CRG New Sanctioned Projects List 2019-20.pdf',multiple_tables=False, pages="all")

df = dfs[0]
df.shape
# Out:
# (6414, 6)

# %%
# first row is column names
# and then drop first row
df.columns = df.iloc[0]
df.drop(labels=0, axis=0,inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# 0 S.No          Discipline                            Sub Area  \
# 0   1.  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 1   2.  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 2   3.  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 3   4.  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
# 4   5.  Chemical\rSciences  Inorganic and\rPhysical\rChemistry
#
# 0                                              Title  \
# 0  Advanced Materials Towards\rElectrocatalytic O...
# 1  Chemistry In Self-Assembled\rCoordination Arch...
# 2  Detoxification of Arsenic\rCompounds: Enzyme M...
# 3  Investigation of Zintl phases as\refficient th...
# 4  High Potency of Complex Dietary\rΒ-Glucan Fibe...
#
# 0                                         PI Details Total Cost
# 0  Tharamani Chikka Nagaiah,\rIndian Institute of...    5783370
# 1  Partha Sarathi Mukherjee,\rIndian Institute of...    5519890
# 2  Gouriprasanna Roy,\rShiv Nadar University,\rGa...    5953775
# 3  Manoj Raama Varma,\rNational Institute For\rIn...    3034800
# 4  Durba Roy,\rBirla Institute of Technology\rAnd...    3666520

# %%
df_1920 = func_clean_df(df)
df_1920.shape
# Out:
# (1041, 6)

# %%
whos DataFrame
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df         DataFrame    0      S.No          Disc<...>\n[6413 rows x 7 columns]
# df_1516    DataFrame         NewSrl  Scheme      <...>n\n[641 rows x 6 columns]
# df_1617    DataFrame         NewSrl           Dis<...>n\n[952 rows x 6 columns]
# df_1718    DataFrame         NewSrl             D<...>n\n[757 rows x 6 columns]
# df_1819    DataFrame          NewSrl             <...>\n[1276 rows x 6 columns]
# df_1920    DataFrame          NewSrl             <...>\n[1041 rows x 6 columns]

# %%
# # Write the files
# df_1516.to_excel('processed/SERB_201516_2.xlsx', index=False)
# df_1617.to_excel('processed/SERB_201617.xlsx', index=False)
# df_1718.to_excel('processed/SERB_201718.xlsx', index=False)
# df_1819.to_excel('processed/SERB_201819.xlsx', index=False)
# df_1920.to_excel('processed/SERB_201920.xlsx', index=False)

# %% [markdown]
# # Clean  the df

# %% [markdown]
# ***Check for nan and spaces in columns***

# %%
# Function to checkc for any na values and check for all spaces in columns -
def func_check_df(df):
    print('Any missing values? - ',df.isnull().values.any())
    print()
    print('Check  for num of blanks in columns :')
    for col in df.select_dtypes(include = ['object']):
        print(col,': ',df[col].str.isspace().sum())

# %% [markdown]
# # 1. Clean 2015-16

# %%
func_check_df(df_1516)
# Out:
# Any missing values? -  False
#
# Check  for num of blanks in columns :
# Scheme :  0
# Title :  0
# PI Name :  116
# Institute & Address :  59

# %%
df_1516.head()
# Out:
#    NewSrl Scheme                                              Title  \
# 0       1    EMR  Development of Sugar amino\racid derived pepti...
# 1       2    EMR  Development of Sugar amino\racid derived pepti...
# 2       3    EMR  Band gap tuning of transtion\rmetal oxides (Zn...
# 3       4    EMR  Investigation of physical aging in\rHigh Tg po...
# 4       5    EMR  Investigation of ultiferroic\rproperties of re...
#
#                           PI Name  \
# 0      Dr.Ravi Shankar\rAmpapathi
# 1  Prof.Tushar Kanti\rChakraborty
# 2               Dr.SanjibKarmakar
# 3              Dr.Asmita Sengupta
# 4             Dr.I.B.Shameem Banu
#
#                                  Institute & Address  Total Cost
# 0  Central Drug Research\rInstitute Lucknow 22603...     2660000
# 1  Indian Institute of Science\rBangalore 560012\...     6384000
# 2          Gauhati University\rGuwahati 781014 Assam     1588800
# 3  Visva -Bharati Central\rUniversity Bolpur\rSan...     1553520
# 4  B.S.Abdur Rahman\rUniversity Chennai 600048\rT...     2355300

# %%
df_1516[df_1516['PI Name'].str.isspace()].head()
# Out:
#     NewSrl     Scheme                                              Title  \
# 11      12     EMR     The bastar carton -the eastern Dr.Pritam Nasip...
# 12      13     EMR     Bioinventorying of Ascomycetus Dr.V.Venkateswa...
# 13      14     EMR     Exploring Heat -stable Rubsico Dr.Ranjeet Ranj...
# 14      15    EMR      RNA-seq for discovery of novel Dr.Tripta Jhang...
# 15      16  EMR        Integrated proteomic Dr.Asish Kumar metabolomi...
#
#    PI Name                                Institute & Address  Total Cost
# 11          Indian Institute of Science Education and Rese...     2323000
# 12          Pondicherry University Puducherry 605014 Puduc...     3961200
# 13          Indian Agriculture Research Institute New Delh...     4833600
# 14          Central Institute of Medicinal & Aromatic Plan...     3768400
# 15          Central Salt and Marine Chemical Research Inst...     2923000

# %% [markdown]
# ***The name is embedded in title***

# %%
df_1516[df_1516['Institute & Address'].str.isspace()].head()
# Out:
#     NewSrl   Scheme                                              Title  \
# 82      83    EMR    Long Term study of the Sun Dr.B.Ravindra using...
# 83      84   EMR     Development of novel Dr.N.Rajendran nanostruct...
# 84      85   EMR     Efficient poly (ethylene oxide ) Dr.Arul Manue...
# 85      86  EMR      Magneto-optic trapping of Dr.Umakant Damodar I...
# 86      87   EMR     Atomistic simulations of boron Dr.Sridhar Sahu...
#
#                                               PI Name Institute & Address  \
# 82  Indian Institute of Astrophysics Bangalore 560...
# 83         Anna University Chennai 600025 Tamilnadu
# 84  Central Electrochemical Research Institute Kar...
# 85   Education and Research Pune 411008 Maharashtra
# 86   Indian School of Mines Dhanbad 826004 Jharkhand
#
#     Total Cost
# 82     2228400
# 83     3456800
# 84     3771000
# 85     5480000
# 86     2523840

# %% [markdown]
# ***The  institue name is in PI name, and the PI name is embedded in the Title***
# ________________________________________________________________
# ***Clean the Title, PI Name and Institue and Address manually***

# %%
df_1516.shape

# %%
df_1516 = pd.read_excel('processed\ed\SERB_15_16V2.xlsx')
df_1516.shape
# Out:
#    NewSrl Scheme                                              Title  \
# 0       1    EMR  Development of Sugar amino_x000D_acid derived ...
# 1       2    EMR  Development of Sugar amino_x000D_acid derived ...
# 2       3    EMR  Band gap tuning of transtion_x000D_metal oxide...
# 3       4    EMR  Investigation of physical aging in_x000D_High ...
# 4       5    EMR  Investigation of ultiferroic_x000D_properties ...
#
#                                PI Name  \
# 0      Dr.Ravi Shankar_x000D_Ampapathi
# 1  Prof.Tushar Kanti_x000D_Chakraborty
# 2                    Dr.SanjibKarmakar
# 3                   Dr.Asmita Sengupta
# 4                  Dr.I.B.Shameem Banu
#
#                                  Institute & Address  Total Cost
# 0  Central Drug Research_x000D_Institute Lucknow ...     2660000
# 1  Indian Institute of Science_x000D_Bangalore 56...     6384000
# 2     Gauhati University_x000D_Guwahati 781014 Assam     1588800
# 3  Visva -Bharati Central_x000D_University Bolpur...     1553520
# 4  B.S.Abdur Rahman_x000D_University Chennai 6000...     2355300

# %%
df_1516.head()

# %%
func_check_df(df_1516)
# Out:
# Any missing values? -  False
#
# Check  for num of blanks in columns :
# Scheme :  0
# Title :  0
# PI Name :  0
# Institute & Address :  0

# %%
df_1516['Title'] = df_1516['Title'].replace('_x000D_', ' ', regex=True)
df_1516['PI Name'] = df_1516['PI Name'].replace('_x000D_', ' ', regex=True)
df_1516['Institute & Address'] = df_1516['Institute & Address'].replace('_x000D_', ' ', regex=True)
df_1516.head()
# Out:
#    NewSrl Scheme                                              Title  \
# 0       1    EMR  Development of Sugar amino acid derived peptid...
# 1       2    EMR  Development of Sugar amino acid derived peptid...
# 2       3    EMR  Band gap tuning of transtion metal oxides (ZnO...
# 3       4    EMR  Investigation of physical aging in High Tg pol...
# 4       5    EMR  Investigation of ultiferroic properties of rer...
#
#                          PI Name  \
# 0      Dr.Ravi Shankar Ampapathi
# 1  Prof.Tushar Kanti Chakraborty
# 2              Dr.SanjibKarmakar
# 3             Dr.Asmita Sengupta
# 4            Dr.I.B.Shameem Banu
#
#                                  Institute & Address  Total Cost
# 0  Central Drug Research Institute Lucknow 226031...     2660000
# 1  Indian Institute of Science Bangalore 560012 K...     6384000
# 2           Gauhati University Guwahati 781014 Assam     1588800
# 3  Visva -Bharati Central University Bolpur Santi...     1553520
# 4  B.S.Abdur Rahman University Chennai 600048 Tam...     2355300

# %%
df_1516['Scheme'].value_counts()
# Out:
# EMR              226
# EMR              152
# EMR              134
# EMR               49
# EMR               45
# EMR               23
# EMR                6
# EMR                3
# EMR                1
# EMR                1
# EMR                1
# Name: Scheme, dtype: int64

# %%
# Remove spaces 
df_1516['Scheme'] = df_1516['Scheme'].str.strip()
df_1516['Title'] = df_1516['Title'].str.strip()
df_1516['PI Name'] = df_1516['PI Name'].str.strip()
df_1516['Institute & Address'] = df_1516['Institute & Address'].str.strip()

# %%
# Rename Scheme to  Discipline
df_1516.rename({'Scheme': 'Discipline'}, axis=1, inplace=True)
# Add SubArea , all other years file has this column
df_1516['Sub Area'] = 'EMR'
df_1516.head()
# Out:
#    NewSrl Discipline                                              Title  \
# 0       1        EMR  Development of Sugar amino acid derived peptid...
# 1       2        EMR  Development of Sugar amino acid derived peptid...
# 2       3        EMR  Band gap tuning of transtion metal oxides (ZnO...
# 3       4        EMR  Investigation of physical aging in High Tg pol...
# 4       5        EMR  Investigation of ultiferroic properties of rer...
#
#                          PI Name  \
# 0      Dr.Ravi Shankar Ampapathi
# 1  Prof.Tushar Kanti Chakraborty
# 2              Dr.SanjibKarmakar
# 3             Dr.Asmita Sengupta
# 4            Dr.I.B.Shameem Banu
#
#                                  Institute & Address  Total Cost Sub Area
# 0  Central Drug Research Institute Lucknow 226031...     2660000      EMR
# 1  Indian Institute of Science Bangalore 560012 K...     6384000      EMR
# 2           Gauhati University Guwahati 781014 Assam     1588800      EMR
# 3  Visva -Bharati Central University Bolpur Santi...     1553520      EMR
# 4  B.S.Abdur Rahman University Chennai 600048 Tam...     2355300      EMR

# %%
# Rename PI Name to Professor
df_1516.rename({'PI Name': 'Professor'}, axis=1, inplace=True)
# Rename Institue and Address to PI Details
df_1516.rename({'Institute & Address': 'PI Details'}, axis=1, inplace=True)

# %%
# Copy PI Deatils to professor
df_1516['Institute'] = df_1516['PI Details']

# %%
df_1516.head()
# Out:
#    NewSrl Discipline                                              Title  \
# 0       1        EMR  Development of Sugar amino acid derived peptid...
# 1       2        EMR  Development of Sugar amino acid derived peptid...
# 2       3        EMR  Band gap tuning of transtion metal oxides (ZnO...
# 3       4        EMR  Investigation of physical aging in High Tg pol...
# 4       5        EMR  Investigation of ultiferroic properties of rer...
#
#                        Professor  \
# 0      Dr.Ravi Shankar Ampapathi
# 1  Prof.Tushar Kanti Chakraborty
# 2              Dr.SanjibKarmakar
# 3             Dr.Asmita Sengupta
# 4            Dr.I.B.Shameem Banu
#
#                                           PI Details  Total Cost Sub Area  \
# 0  Central Drug Research Institute Lucknow 226031...     2660000      EMR
# 1  Indian Institute of Science Bangalore 560012 K...     6384000      EMR
# 2           Gauhati University Guwahati 781014 Assam     1588800      EMR
# 3  Visva -Bharati Central University Bolpur Santi...     1553520      EMR
# 4  B.S.Abdur Rahman University Chennai 600048 Tam...     2355300      EMR
#
#                                            Institute
# 0  Central Drug Research Institute Lucknow 226031...
# 1  Indian Institute of Science Bangalore 560012 K...
# 2           Gauhati University Guwahati 781014 Assam
# 3  Visva -Bharati Central University Bolpur Santi...
# 4  B.S.Abdur Rahman University Chennai 600048 Tam...

# %% [markdown]
# # 2. Clean 2016-17

# %%
func_check_df(df_1617)
# Out:
# Any missing values? -  False
#
# Check  for num of blanks in columns :
# Discipline :  108
# Sub Area :  0
# Title :  0
# PI Details :  0

# %%
df_1617.head()
# Out:
#    NewSrl          Discipline                          Sub Area  \
# 0       1  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 1       2  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 2       3  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 3       4  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
# 4       5  Chemical\rSciences  Inorganic &\rPhysical\rChemistry
#
#                                                Title  \
# 0  Investigation on the effect of ionic\rliquids ...
# 1  Optical And Electrochemical Sensors\rbased on ...
# 2  A Concerted drive towards ambient\rpressure sy...
# 3  Estimation of nanoparticles (Toxic\rmetals) Fr...
# 4  Investigation on an Electrochemical\rsystem co...
#
#                                           PI Details  Total Cost
# 0  Dr. Harsh Kumar Manchanda,\rDepartment of Chem...     3300000
# 1  Dr. Shweta Rana,\rDepartment of Chemistry,\rPa...     3025000
# 2  Dr.Md. Motin Seikh,\rDepartment of Chemistry,\...     3739560
# 3  Dr. Kalpana Kumari,\rDepartment of Chemistry,\...     1900800
# 4  Dr. Anudeep Kumar Narula,\rGuru Gobind Singh I...     3185600

# %%
df_1617[df_1617['Discipline'].str.isspace()].head()
# Out:
#      NewSrl Discipline                          Sub Area  \
# 96       97              Inorganic & Physical Chemistry
# 97       98             Inorganic & Physical Chemistry
# 98       99             Inorganic & Physical Chemistry
# 99      100             Inorganic & Physical Chemistry
# 100     101              Inorganic & Physical Chemistry
#
#                                                  Title  \
# 96   Synthesis and characterization of chitosan bas...
# 97   Molecular recognition receptors for biomarkers...
# 98   Temperature dependent semiconductor properties...
# 99   Tailoring rare earth element additions in zirc...
# 100  Continuous Flow An Attempt to miniaturization ...
#
#                                             PI Details  Total Cost
# 96   Prof. Sankaran Meenakshi, Department of Chemis...     1909600
# 97   Dr. Amitava Das, Department of Chemistry, Cent...     7354370
# 98   Dr. Pankaj Kumar Mandal, Department of Chemist...     8575910
# 99   Dr. Kannan Sanjeevi, Centre For Nano Science a...     4274600
# 100  Dr. Ramesh C. Deka, Department of Chemical Sci...     4740120

# %%
# All spaces in Discipline are Chemical Sciences
df_1617['Discipline'] = np.where(df_1617['Discipline'].str.isspace(),'Chemical Sciences',df_1617['Discipline'])

# %%
# Remove spaces
df_1617['Discipline'] = df_1617['Discipline'].str.strip()
df_1617['Sub Area'] = df_1617['Sub Area'].str.strip()
df_1617['Title'] = df_1617['Title'].str.strip()
df_1617['PI Details'] = df_1617['PI Details'].str.strip()

# %%
# Remove all carriage return
df_1617.replace(r'\r', ' ', regex = True, inplace = True)

# %%
# Split PI to get professor and Institutes name,  if not str[0], we get a list 
df_1617['Professor'] = df_1617['PI Details'].str.split(',').str[0]
df_1617['Institute'] = df_1617['PI Details'].str.split(',',1).str[1]
df_1617.head()
# Out:
#    NewSrl         Discipline                        Sub Area  \
# 0       1  Chemical Sciences  Inorganic & Physical Chemistry
# 1       2  Chemical Sciences  Inorganic & Physical Chemistry
# 2       3  Chemical Sciences  Inorganic & Physical Chemistry
# 3       4  Chemical Sciences  Inorganic & Physical Chemistry
# 4       5  Chemical Sciences  Inorganic & Physical Chemistry
#
#                                                Title  \
# 0  Investigation on the effect of ionic liquids o...
# 1  Optical And Electrochemical Sensors based on B...
# 2  A Concerted drive towards ambient pressure syn...
# 3  Estimation of nanoparticles (Toxic metals) Fro...
# 4  Investigation on an Electrochemical system com...
#
#                                           PI Details  Total Cost  \
# 0  Dr. Harsh Kumar Manchanda, Department of Chemi...     3300000
# 1  Dr. Shweta Rana, Department of Chemistry, Panj...     3025000
# 2  Dr.Md. Motin Seikh, Department of Chemistry, V...     3739560
# 3  Dr. Kalpana Kumari, Department of Chemistry, B...     1900800
# 4  Dr. Anudeep Kumar Narula, Guru Gobind Singh In...     3185600
#
#                    Professor  \
# 0  Dr. Harsh Kumar Manchanda
# 1            Dr. Shweta Rana
# 2         Dr.Md. Motin Seikh
# 3         Dr. Kalpana Kumari
# 4   Dr. Anudeep Kumar Narula
#
#                                            Institute
# 0   Department of Chemistry, Dr.B R Ambedkar Nati...
# 1   Department of Chemistry, Panjab University, C...
# 2   Department of Chemistry, Visva Bharati Univer...
# 3   Department of Chemistry, Birchand Patel Smara...
# 4   Guru Gobind Singh Indraprastha University,New...

# %%
df_1516.columns
# Out:
# Index(['NewSrl', 'Discipline', 'Title', 'Professor', 'PI Details',
#        'Total Cost', 'Sub Area', 'Institute'],
#       dtype='object')

# %%
df_1617.columns
# Out:
# Index(['NewSrl', 'Discipline', 'Sub Area', 'Title', 'PI Details', 'Total Cost',
#        'Professor', 'Institute'],
#       dtype='object')

# %% [markdown]
# # 3. Clean 2017-18

# %%
func_check_df(df_1718)
# Out:
# Any missing values? -  False
#
# Check  for num of blanks in columns :
# Discipline :  0
# Sub Area :  0
# Title :  0
# PI Details :  0

# %%
df_1718['Discipline'] = df_1718['Discipline'].str.strip()
df_1718['Sub Area'] = df_1718['Sub Area'].str.strip()
df_1718['Title'] = df_1718['Title'].str.strip()
df_1718['PI Details'] = df_1718['PI Details'].str.strip()
# remove carriage return
df_1718.replace(r'\r', ' ', regex = True, inplace = True)
df_1718.head()
# Out:
#    NewSrl        Discipline                          Sub Area  \
# 0       1  Chemical Science  Inorganic and Physical Chemistry
# 1       2  Chemical Science  Inorganic and Physical Chemistry
# 2       3  Chemical Science  Inorganic and Physical Chemistry
# 3       4  Chemical Science  Inorganic and Physical Chemistry
# 4       5  Chemical Science  Inorganic and Physical Chemistry
#
#                                                Title  \
# 0   Surface anchored metal organic thin film devices
# 1  Design of diagnostic tools to monitor certain ...
# 2  Coordination complexes of organic radicals sys...
# 3  Exploration of key photinduced dyanmics in ino...
# 4  Metal Complexes based probes for arylamine mod...
#
#                                           PI Details  Total Cost
# 0  Dr. Nirmalya Ballav, Indian institute of Scien...     6803280
# 1  Dr. Meenakshi Singh, Banaras Hindu University,...     4387810
# 2  Dr. Prasanta Ghosh, Ramakrishna Mission Reside...     4163280
# 3  Dr. Samir Kumar Pal, S N Bose National Centre ...     1998000
# 4  Dr. Dr. Vaidyanathan Ganesan, Central Leather ...     2286145

# %%
# Split PI to get professor and Institutes name,  if not str[0], we get a list 
df_1718['Professor'] = df_1718['PI Details'].str.split(',').str[0]
df_1718['Institute'] = df_1718['PI Details'].str.split(',',1).str[1]
df_1718.head()
# Out:
#    NewSrl        Discipline                          Sub Area  \
# 0       1  Chemical Science  Inorganic and Physical Chemistry
# 1       2  Chemical Science  Inorganic and Physical Chemistry
# 2       3  Chemical Science  Inorganic and Physical Chemistry
# 3       4  Chemical Science  Inorganic and Physical Chemistry
# 4       5  Chemical Science  Inorganic and Physical Chemistry
#
#                                                Title  \
# 0   Surface anchored metal organic thin film devices
# 1  Design of diagnostic tools to monitor certain ...
# 2  Coordination complexes of organic radicals sys...
# 3  Exploration of key photinduced dyanmics in ino...
# 4  Metal Complexes based probes for arylamine mod...
#
#                                           PI Details  Total Cost  \
# 0  Dr. Nirmalya Ballav, Indian institute of Scien...     6803280
# 1  Dr. Meenakshi Singh, Banaras Hindu University,...     4387810
# 2  Dr. Prasanta Ghosh, Ramakrishna Mission Reside...     4163280
# 3  Dr. Samir Kumar Pal, S N Bose National Centre ...     1998000
# 4  Dr. Dr. Vaidyanathan Ganesan, Central Leather ...     2286145
#
#                       Professor  \
# 0           Dr. Nirmalya Ballav
# 1           Dr. Meenakshi Singh
# 2            Dr. Prasanta Ghosh
# 3           Dr. Samir Kumar Pal
# 4  Dr. Dr. Vaidyanathan Ganesan
#
#                                            Institute
# 0   Indian institute of Science Education and Res...
# 1   Banaras Hindu University, Varanasi, Uttar Pra...
# 2   Ramakrishna Mission Residential College, Kolk...
# 3   S N Bose National Centre for Basic Sciences, ...
# 4   Central Leather Research institute, Chennai, ...

# %% [markdown]
# # 4. Clean 2018-19

# %%
func_check_df(df_1819)
# Out:
# Any missing values? -  False
#
# Check  for num of blanks in columns :
# Discipline :  0
# Sub Area :  0
# Title :  0
# PI Details :  0

# %%
df_1819['Discipline'] = df_1819['Discipline'].str.strip()
df_1819['Sub Area'] = df_1819['Sub Area'].str.strip()
df_1819['Title'] = df_1819['Title'].str.strip()
df_1819['PI Details'] = df_1819['PI Details'].str.strip()
df_1819.replace(r'\r', ' ', regex = True, inplace = True)
df_1819.head()
# Out:
#    NewSrl         Discipline                          Sub Area  \
# 0       1  Chemical Sciences  Inorganic and Physical Chemistry
# 1       2  Chemical Sciences  Inorganic and Physical Chemistry
# 2       3  Chemical Sciences  Inorganic and Physical Chemistry
# 3       4  Chemical Sciences  Inorganic and Physical Chemistry
# 4       5  Chemical Sciences  Inorganic and Physical Chemistry
#
#                                                Title  \
# 0  Photothermal Properties of Anisotropic Metal N...
# 1  Highly Selective Ring-Opening Polymerization o...
# 2  Synthesis, Characterization And Catalytic Appl...
# 3  Integrated Gravity Flow Water Filtration Syste...
# 4  Novel Electrode Materials For Reversible Alkal...
#
#                                           PI Details  Total Cost
# 0  Dr. Sujit Kumar Ghosh, Assam University, Silch...     2562560
# 1  Dr. Tarun Kanti Panda, Indian Institute of Tec...     6508480
# 2  Dr. Firasat Hussain, University of Delhi, Delh...     3520000
# 3  Dr. Raj Kishore Patel, National Institute of T...     3658600
# 4  Dr. Preetam Singh, Indian Institute of Technol...     3665245

# %%
# Split PI to get professor and Institutes name,  if not str[0], we get a list 
df_1819['Professor'] = df_1819['PI Details'].str.split(',').str[0]
df_1819['Institute'] = df_1819['PI Details'].str.split(',',1).str[1]
df_1819.head()
# Out:
#    NewSrl         Discipline                          Sub Area  \
# 0       1  Chemical Sciences  Inorganic and Physical Chemistry
# 1       2  Chemical Sciences  Inorganic and Physical Chemistry
# 2       3  Chemical Sciences  Inorganic and Physical Chemistry
# 3       4  Chemical Sciences  Inorganic and Physical Chemistry
# 4       5  Chemical Sciences  Inorganic and Physical Chemistry
#
#                                                Title  \
# 0  Photothermal Properties of Anisotropic Metal N...
# 1  Highly Selective Ring-Opening Polymerization o...
# 2  Synthesis, Characterization And Catalytic Appl...
# 3  Integrated Gravity Flow Water Filtration Syste...
# 4  Novel Electrode Materials For Reversible Alkal...
#
#                                           PI Details  Total Cost  \
# 0  Dr. Sujit Kumar Ghosh, Assam University, Silch...     2562560
# 1  Dr. Tarun Kanti Panda, Indian Institute of Tec...     6508480
# 2  Dr. Firasat Hussain, University of Delhi, Delh...     3520000
# 3  Dr. Raj Kishore Patel, National Institute of T...     3658600
# 4  Dr. Preetam Singh, Indian Institute of Technol...     3665245
#
#                Professor                                          Institute
# 0  Dr. Sujit Kumar Ghosh           Assam University, Silchar, Assam, 788011
# 1  Dr. Tarun Kanti Panda   Indian Institute of Technology Hyderabad, Hyd...
# 2    Dr. Firasat Hussain          University of Delhi, Delhi, Delhi, 110007
# 3  Dr. Raj Kishore Patel   National Institute of Technology Rourkela, Ro...
# 4      Dr. Preetam Singh   Indian Institute of Technology (Bhu), Varanas...

# %% [markdown]
# # 5. Clean 2019-20

# %%
func_check_df(df_1920)
# Out:
# Any missing values? -  False
#
# Check  for num of blanks in columns :
# Discipline :  0
# Sub Area :  0
# Title :  0
# PI Details :  0

# %%
df_1920['Discipline'] = df_1920['Discipline'].str.strip()
df_1920['Sub Area'] = df_1920['Sub Area'].str.strip()
df_1920['Title'] = df_1920['Title'].str.strip()
df_1920['PI Details'] = df_1920['PI Details'].str.strip()
df_1920.replace(r'\r', ' ', regex = True, inplace = True)

# %%
# Split PI to get professor and Institutes name,  if not str[0], we get a list 
df_1920['Professor'] = df_1920['PI Details'].str.split(',').str[0]
df_1920['Institute'] = df_1920['PI Details'].str.split(',',1).str[1]
df_1920.head()
# Out:
#    NewSrl         Discipline                          Sub Area  \
# 0       1  Chemical Sciences  Inorganic and Physical Chemistry
# 1       2  Chemical Sciences  Inorganic and Physical Chemistry
# 2       3  Chemical Sciences  Inorganic and Physical Chemistry
# 3       4  Chemical Sciences  Inorganic and Physical Chemistry
# 4       5  Chemical Sciences  Inorganic and Physical Chemistry
#
#                                                Title  \
# 0  Advanced Materials Towards Electrocatalytic Ox...
# 1  Chemistry In Self-Assembled Coordination Archi...
# 2  Detoxification of Arsenic Compounds: Enzyme Mi...
# 3  Investigation of Zintl phases as efficient the...
# 4  High Potency of Complex Dietary Β-Glucan Fiber...
#
#                                           PI Details  Total Cost  \
# 0  Tharamani Chikka Nagaiah, Indian Institute of ...     5783370
# 1  Partha Sarathi Mukherjee, Indian Institute of ...     5519890
# 2  Gouriprasanna Roy, Shiv Nadar University, Gaut...     5953775
# 3  Manoj Raama Varma, National Institute For Inte...     3034800
# 4  Durba Roy, Birla Institute of Technology And S...     3666520
#
#                   Professor                                          Institute
# 0  Tharamani Chikka Nagaiah   Indian Institute of Technology Ropar, Ropar,P...
# 1  Partha Sarathi Mukherjee   Indian Institute of Science,Bangalore, Bangal...
# 2         Gouriprasanna Roy   Shiv Nadar University, Gautambudh Nagar,Uttar...
# 3         Manoj Raama Varma   National Institute For Interdisciplinary Scie...
# 4                 Durba Roy   Birla Institute of Technology And Science Pil...

# %% [markdown]
# # Merge all and then clean Disciplinne, sub area and get pic cd and State

# %%
df_1516['Year'] = '2015-16'
df_1617['Year'] = '2016-17'
df_1718['Year'] = '2017-18'
df_1819['Year'] = '2018-19'
df_1920['Year'] = '2019-20'

# %%
# The cols sequence is based on  first data frame 
df = pd.concat([df_1920,df_1819,df_1718,df_1617,df_1516],ignore_index=True)
df.drop(['NewSrl'], axis = 1,inplace=True)
#df.rename({'pin_cd': 'Pin Code'}, axis=1, inplace=True)
#pd.set_option("precision", 1)
df.shape
# Out:
# (4667, 8)

# %%
df.head()
# Out:
#           Discipline                          Sub Area  \
# 0  Chemical Sciences  Inorganic and Physical Chemistry
# 1  Chemical Sciences  Inorganic and Physical Chemistry
# 2  Chemical Sciences  Inorganic and Physical Chemistry
# 3  Chemical Sciences  Inorganic and Physical Chemistry
# 4  Chemical Sciences  Inorganic and Physical Chemistry
#
#                                                Title  \
# 0  Advanced Materials Towards Electrocatalytic Ox...
# 1  Chemistry In Self-Assembled Coordination Archi...
# 2  Detoxification of Arsenic Compounds: Enzyme Mi...
# 3  Investigation of Zintl phases as efficient the...
# 4  High Potency of Complex Dietary Β-Glucan Fiber...
#
#                                           PI Details  Total Cost  \
# 0  Tharamani Chikka Nagaiah, Indian Institute of ...     5783370
# 1  Partha Sarathi Mukherjee, Indian Institute of ...     5519890
# 2  Gouriprasanna Roy, Shiv Nadar University, Gaut...     5953775
# 3  Manoj Raama Varma, National Institute For Inte...     3034800
# 4  Durba Roy, Birla Institute of Technology And S...     3666520
#
#                   Professor  \
# 0  Tharamani Chikka Nagaiah
# 1  Partha Sarathi Mukherjee
# 2         Gouriprasanna Roy
# 3         Manoj Raama Varma
# 4                 Durba Roy
#
#                                            Institute     Year
# 0   Indian Institute of Technology Ropar, Ropar,P...  2019-20
# 1   Indian Institute of Science,Bangalore, Bangal...  2019-20
# 2   Shiv Nadar University, Gautambudh Nagar,Uttar...  2019-20
# 3   National Institute For Interdisciplinary Scie...  2019-20
# 4   Birla Institute of Technology And Science Pil...  2019-20

# %% [markdown]
# # Clean Discipline

# %%
df.isna().sum()
# Out:
# Discipline    0
# Sub Area      0
# Title         0
# PI Details    0
# Total Cost    0
# Professor     0
# Institute     0
# Year          0
# dtype: int64

# %%
df['Discipline'].value_counts()
# Out:
# Life Sciences                      1095
# EMR                                 641
# Engineering Sciences                404
# Chemical Sciences                   403
# Life  Sciences                      366
# Physical Sciences                   287
# Chemical  Sciences                  201
# Engineering  Sciences               189
# Phy sical Sciences                  172
# Chemical Science                    172
# Physical  Sciences                  171
# Eng ineering Sciences               137
# L ife Sciences                      133
# Earth & Atmospheric Sciences         62
# Earth &  Atmospheric  Sciences       55
# Mathematical Sciences                53
# Mathematical  Sciences               47
# Ma thematical Sciences               38
# Ear th and Atmospheric Sciences      33
# Combustion                            6
# busion                                2
# Name: Discipline, dtype: int64

# %%
# From 1920
df['Discipline'] = df['Discipline'].str.replace('L ife Sciences', 'Life Sciences')
# From1819
df['Discipline'] = df['Discipline'].str.replace('Physical  Sciences', 'Physical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Engineering  Sciences', 'Engineering Sciences')
df['Discipline'] = df['Discipline'].str.replace('Chemical  Sciences', 'Chemical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Mathematical  Sciences', 'Mathematical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Earth &  Atmospheric  Sciences', 'Earth & Atmospheric Sciences')
# From 1718
df['Discipline'] = df['Discipline'].str.replace('Chemical Science', 'Chemical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Combustion', 'Chemical Sciences')
#From 1617
df['Discipline'] = df['Discipline'].str.replace('Life  Sciences', 'Life Sciences')
df['Discipline'] = df['Discipline'].str.replace('Phy sical Sciences', 'Physical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Eng ineering Sciences', 'Engineering Sciences')
#df_1617['Discipline'] = df_1617['Discipline'].str.replace('Chemical Science', 'Chemical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Ma thematical Sciences', 'Mathematical Sciences')
df['Discipline'] = df['Discipline'].str.replace('Ear th and Atmospheric Sciences', 'Earth & Atmospheric Sciences')
df['Discipline'] = df['Discipline'].str.replace('busion', 'Chemical Sciences')

# %%
df['Discipline'].value_counts()
# Out:
# Life Sciences                   1594
# Engineering Sciences             730
# EMR                              641
# Physical Sciences                630
# Chemical Sciencess               604
# Chemical Sciences                180
# Earth & Atmospheric Sciences     150
# Mathematical Sciences            138
# Name: Discipline, dtype: int64

# %% [markdown]
# # Clean  Sub Area

# %%
df['Sub Area'].value_counts()
# Out:
# EMR                                                               641
# Physical Sciences                                                 459
# Health Sciences                                                   339
# Plant Sciences                                                    250
# Inorganic and Physical Chemistry                                  229
# Health  Sciences                                                  223
# Organic Chemistry                                                 218
# Electrical, Electronics & Computer Engineering                    193
# Physical  Sciences                                                171
# Animal Sciences                                                   129
# Animal  Sciences                                                  129
# Inorganic & Physical Chemistry                                    128
# Inorganic and  Physical  Chemistry                                116
# Materials, Mining & Minerals Engineering                          111
# Biophysics,  Biochemistry,  Molecular  Biology &  Microbiology    109
# Biophysics, Biochemistry, Molecular Biology & Microbiology         95
# Mathematical Sciences                                              91
# Biomedical And Health Sciences                                     86
# Organic  Chemistry                                                 85
# Biochemistry, Biophysics, Molecular Biology & Microbiology         83
# Civil And Mechanical Engineering                                   79
# Interdiscipilnary Biological Sciences                              71
# Earth &  Atmospheric  Sciences                                     55
# Earth and Atmospheric Sciences                                     49
# Electrical,  Electronics &  Computer  Engineering                  48
# Mathematical  Sciences                                             47
# Organismal And Evolutionary Biology (Plant Science)                46
# Earth & Atmospheric Sciences                                       46
# Civil and  Mechanical  Engineering                                 44
# Chemical &  Environmental  Engineering                             43
# Civil and Mechanical Engineering                                   34
# Chemical and Environmental Engineering                             33
# Chemical & Environmental Engineering                               33
# Organismal And Evolutionary Biology (Animal Science)               29
# Civil, Mechanical Engineering                                      29
# Chemical And Environmental Engineering                             28
# Materials,  Mining &  Minerals  Engineering                        28
# Electrical, Electronics &  Computer Engineering                    21
# Engineering Science                                                 6
# Materials, Mining &  Minerals Engineering                           6
# Biophysics, Biochemistry,  Molecular  Biology & Microbiology        3
# Combusion                                                           2
# Organismal And Evolutionary Biology (Palant Science)                1
# Organismal And Evolutionary  Biology (Palant Science)               1
# Name: Sub Area, dtype: int64

# %%
# From 1920
df['Sub Area'] = df['Sub Area'].str.replace('Organismal And Evolutionary  Biology (Palant Science)', 
                                                      'Organismal And Evolutionary Biology (Plant Science)',regex=False)

df['Sub Area'] = df['Sub Area'].str.replace('Organismal And Evolutionary Biology (Palant Science)', 
                                                      'Organismal And Evolutionary Biology (Plant Science)',regex=False)

df['Sub Area'] = df['Sub Area'].str.replace('Electrical, Electronics &  Computer Engineering', 
                                                      'Electrical, Electronics & Computer Engineering',regex=False)

# From 1819
#to be done...not done previously...allneeds to be edited....

# from 1718
# Nothing

# From 1617
df['Sub Area'] = df['Sub Area'].str.replace('Combusion', 
                                                      'Inorganic & Physical Chemistry',regex=False)

#

# %%
df['Sub Area'].value_counts()
# Out:
# EMR                                                               641
# Physical Sciences                                                 459
# Health Sciences                                                   339
# Plant Sciences                                                    250
# Inorganic and Physical Chemistry                                  229
# Health  Sciences                                                  223
# Organic Chemistry                                                 218
# Electrical, Electronics & Computer Engineering                    214
# Physical  Sciences                                                171
# Inorganic & Physical Chemistry                                    130
# Animal  Sciences                                                  129
# Animal Sciences                                                   129
# Inorganic and  Physical  Chemistry                                116
# Materials, Mining & Minerals Engineering                          111
# Biophysics,  Biochemistry,  Molecular  Biology &  Microbiology    109
# Biophysics, Biochemistry, Molecular Biology & Microbiology         95
# Mathematical Sciences                                              91
# Biomedical And Health Sciences                                     86
# Organic  Chemistry                                                 85
# Biochemistry, Biophysics, Molecular Biology & Microbiology         83
# Civil And Mechanical Engineering                                   79
# Interdiscipilnary Biological Sciences                              71
# Earth &  Atmospheric  Sciences                                     55
# Earth and Atmospheric Sciences                                     49
# Electrical,  Electronics &  Computer  Engineering                  48
# Organismal And Evolutionary Biology (Plant Science)                48
# Mathematical  Sciences                                             47
# Earth & Atmospheric Sciences                                       46
# Civil and  Mechanical  Engineering                                 44
# Chemical &  Environmental  Engineering                             43
# Civil and Mechanical Engineering                                   34
# Chemical and Environmental Engineering                             33
# Chemical & Environmental Engineering                               33
# Organismal And Evolutionary Biology (Animal Science)               29
# Civil, Mechanical Engineering                                      29
# Chemical And Environmental Engineering                             28
# Materials,  Mining &  Minerals  Engineering                        28
# Materials, Mining &  Minerals Engineering                           6
# Engineering Science                                                 6
# Biophysics, Biochemistry,  Molecular  Biology & Microbiology        3
# Name: Sub Area, dtype: int64

# %%
# Clean soome more of sub arae

# %% [markdown]
# # Not get pin code and State
